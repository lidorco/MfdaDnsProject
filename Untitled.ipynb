# %%
import glob
import os
import pandas as pd
import copy
import datetime
import json
from functools import reduce
from time import time
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle
from xgboost import XGBClassifier

# %% [markdown]
# # CONSTS

# %%
DATA_PATH = r".\data\raw\*.csv"

TOP_DOMAIN_USAGES = 100
DOMAIN_COUNT_THRESHOLD = 1

NUMBER_OF_QUERIES_EACH_CHUNK = 750
NUMBER_OF_USERS = 15

LEARNING_CHUNKS = 50
TESTING_CHUNKS = 40
USEABLE_CHUNKS = LEARNING_CHUNKS + TESTING_CHUNKS

COMMON_DOMAIN_COUNT = 100

# %%
users_data = []
for file in glob.glob(DATA_PATH):
    df = pd.DataFrame()
    df = df.from_csv(file)
    user_id = int(os.path.basename(file).split('.')[0].split('_user')[1])
    df['user'] = pd.Series([user_id] * len(df.index), index=df.index)
    users_data.append(df)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:3214: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:3214: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %% [markdown]
# # Explore Data

# %%
len(users_data)
# Out:
# 15

# %%
print("number of columns: {}\n columns: {}\n".format(len(users_data[0].columns), users_data[0].columns))
# Out:
# number of columns: 27
#  columns: Index(['frame.time_epoch', 'frame.time_relative', 'ip.dst', 'ip.src',
#        'tcp.srcport', 'tcp.dstport', 'udp.srcport', 'udp.dstport',
#        'dns.qry.type', 'dns.qry.name', 'dns.resp.type', 'dns.resp.name',
#        'dns.resp.ttl', 'dns.a', 'dns.aaaa', 'dns.cname', 'dns.flags',
#        'dns.flags.response', 'dns.flags.rcode', 'dns.count.queries',
#        'dns.count.answers', 'dns.count.auth_rr', 'dns.count.add_rr',
#        'dns.soa.mname', 'dns.srv.name', 'dns.time', 'user'],
#       dtype='object')

# %%
def calculate_domains_stats(): 
    sum = 0
    min = 99999999
    max = 0
    for user in users_data:
        sum += len(user.index)
        if min > len(user.index):
            min = len(user.index)
        if max < len(user.index):
            max = len(user.index)
        # print("rows: {}".format(len(user.index)))
    print("rows avg: {}".format(sum / len(users_data)))
    print("rows min: {}".format(min))
    print("rows max: {}".format(max))
calculate_domains_stats()
# Out:
# rows avg: 210466.86666666667
# rows min: 141471
# rows max: 328846

# %% [markdown]
# # Explore Domains

# %%
domains_per_user = []
for s in [user['dns.qry.name'].unique() for user in users_data]:
    domains_per_user.append(set(s))

# %%
known_domains = pd.Series(reduce(lambda x, y: list(set(x).union(y)), domains_per_user))
known_domains = known_domains.unique()
print("Number of different domains in all data : {}".format(len(known_domains)))
# Out:
# Number of different domains in all data : 47044

# %%
# avg of unique domains per user:
sum_domains = reduce(lambda x, y: x + y, [len(user['dns.qry.name'].unique()) for user in users_data])
min_domains = reduce(lambda x, y: min(x, y), [len(user['dns.qry.name'].unique()) for user in users_data])
max_domains = reduce(lambda x, y: max(x, y), [len(user['dns.qry.name'].unique()) for user in users_data])
print("Average of domains without duplication per user : {}".format(sum_domains / len(users_data)))
print("Min of domains without duplication per user : {}".format(min_domains))
print("Max of domains without duplication per user : {}".format(max_domains))
# Out:
# Average of domains without duplication per user : 4236.533333333334
# Min of domains without duplication per user : 2534
# Max of domains without duplication per user : 6006

# %%
# avg time for pcap per user
users_sniff_time = [datetime.timedelta(seconds=int(user['frame.time_relative'].max())) for user in users_data]
print("Average of sniff time per user : {}".format(
    reduce(lambda x, y: x + y, users_sniff_time) / len(users_sniff_time)))
print("Min of sniff time per user : {}".format(min(users_sniff_time)))
print("Max of sniff time per user : {}".format(max(users_sniff_time)))
# Out:
# Average of sniff time per user : 36 days, 5:47:32.066667
# Min of sniff time per user : 30 days, 19:32:27
# Max of sniff time per user : 57 days, 21:39:32

# %%
# domain used only by specific user
def calc_unique_domains():
    user_sum = 0
    for index, user in enumerate(domains_per_user):
        user_domains = copy.deepcopy(user)
        for u in domains_per_user[:index]:
            user_domains -= u

        for u in domains_per_user[index + 1:]:
            user_domains -= u

        user_sum += len(user_domains)
        print("Unique domain for user {} is {}".format(index, len(user_domains)))
    
    print("Average of domains only used by specific users : {}".format(user_sum / len(users_data)))
calc_unique_domains()
# Out:
# Unique domain for user 0 is 1086
# Unique domain for user 1 is 4152
# Unique domain for user 2 is 2334
# Unique domain for user 3 is 5351
# Unique domain for user 4 is 1981
# Unique domain for user 5 is 3503
# Unique domain for user 6 is 2620
# Unique domain for user 7 is 1856
# Unique domain for user 8 is 2949
# Unique domain for user 9 is 1909
# Unique domain for user 10 is 5092
# Unique domain for user 11 is 1718
# Unique domain for user 12 is 1535
# Unique domain for user 13 is 4435
# Unique domain for user 14 is 2667
# Average of domains only used by specific users : 2879.2

# %%
# top domain usages:
all_domains = []
for s in [user['dns.qry.name'].unique() for user in users_data]:
    all_domains.extend(s)
all_domains
# Out:
# ['android.clients.google.com',
#  'urlauth.ksmobile.net',
#  'streamer.bizportal.co.il',
#  'app.woorlds.com',
#  'logjam.cyngn.com',
#  'ws.pushapps.mobi',
#  'www.quickode.com',
#  'www.googleapis.com',
#  'ssl.gstatic.com',
#  'docs.google.com',
#  'clients3.google.com',
#  'csi.gstatic.com',
#  'lh5.googleusercontent.com',
#  'lh6.googleusercontent.com',
#  'lh3.googleusercontent.com',
#  'up.cm.ksmobile.com',
#  'edge-mqtt.facebook.com',
#  'news.google.com',
#  'mclients.googleapis.com',
#  'touch.www.linkedin.com',
#  'graph.facebook.com',
#  'a.config.skype.com',
#  'inbox.google.com',
#  'api.crittercism.com',
#  'gemiuscookie.hit.gemius.pl',
#  'upoll.umengcloud.com',
#  'play.googleapis.com',
#  'spengler.mobilethreat.net',
#  'appinfocdn.ksmobile.net',
#  'settings.crashlytics.com',
#  'decide.mixpanel.com',
#  'infoc2.duba.net',
#  'device-api.urbanairship.com',
#  '1e58de17.api.splkmobile.com',
#  '130.231.215.54.in-addr.arpa',
#  'utop.umengcloud.com',
#  'adash.m.taobao.com',
#  'secure-drm.imrworldwide.com',
#  'clients4.google.com',
#  'svcs.droidux.com',
#  'cmdts.ksmobile.com',
#  'mtalk.google.com',
#  'www.cm.ksmobile.com',
#  'dcys-en.ijinshan.com',
#  'api.mixpanel.com',
#  'mail.google.com',
#  'accounts.google.com',
#  'mail-attachment.googleusercontent.com',
#  'e16.whatsapp.net',
#  'shopvac.cyngn.com',
#  'weather.ios.ijinshan.com',
#  'ssl.google-analytics.com',
#  'play.google.com',
#  'newsstand.googleusercontent.com',
#  'zj.dcys.ksmobile.com',
#  'android.googleapis.com',
#  'www.googleadservices.com',
#  'www.google.com',
#  'translate.googleapis.com',
#  'www.alljobs.co.il',
#  'tools.google.com',
#  'sgomceormhuzptg',
#  'ywbqhawr',
#  'otalpsqu',
#  'www.google-analytics.com',
#  'stats.g.doubleclick.net',
#  'dnn506yrbagrg.cloudfront.net',
#  'track.appsflyer.com',
#  '3.112.252.173.in-addr.arpa',
#  'weather.yahooapis.com',
#  'cml.ksmobile.com',
#  'dl.sj.ijinshan.com',
#  'fbcdn-profile-a.akamaihd.net',
#  'api.facebook.com',
#  'ci3.googleusercontent.com',
#  'ci5.googleusercontent.com',
#  'www.linkedin.com',
#  'sdk.fiksu.com',
#  'fbcdn-video-b-a.akamaihd.net',
#  'fbcdn-sphotos-f-a.akamaihd.net',
#  'fbcdn-sphotos-d-a.akamaihd.net',
#  'scontent-fra.xx.fbcdn.net',
#  'fbcdn-sphotos-g-a.akamaihd.net',
#  'fbexternal-a.akamaihd.net',
#  'fbcdn-video-l-a.akamaihd.net',
#  'scontent.xx.fbcdn.net',
#  'fbcdn-video-n-a.akamaihd.net',
#  'fbcdn-video-k-a.akamaihd.net',
#  'e15.whatsapp.net',
#  'www.google.co.il',
#  'ud.adkmob.com',
#  'mmv205.whatsapp.net',
#  '12.152.220.66.in-addr.arpa',
#  'behacdn.ksmobile.net',
#  '2.110.252.173.in-addr.arpa',
#  'p-behacdn.ksmobile.net',
#  'cp.pushwoosh.com',
#  'b-graph.facebook.com',
#  'ssdk.adkmob.com',
#  'www.facebook.com',
#  'e13.whatsapp.net',
#  'api.appoxee.com',
#  'content.cdn.viber.com',
#  'kbd1.kpns.ijinshan.com',
#  'www.themarker.com',
#  'data.flurry.com',
#  'media.admob.com',
#  'finapi.themarker.com',
#  'pubads.g.doubleclick.net',
#  'www.googletagservices.com',
#  'gail.hit.gemius.pl',
#  'rep.erate.co.il',
#  'media.erate.co.il',
#  'pagead2.googlesyndication.com',
#  'cm.g.doubleclick.net',
#  'adxhm.d.chango.com',
#  'kbd.utag.ksmobile.com',
#  'www.gstatic.com',
#  'b.config.skype.com',
#  'api.skype.com',
#  'BAYMSGR1010507.gateway.messenger.live.com',
#  'dsn5.d.skype.net',
#  '65524.0.3.5.20703.rst0.r.skype.net',
#  'api.trap.skype.net',
#  'api.mcr.skype.com',
#  'pipe.skype.com',
#  'people.directory.live.com',
#  'dl.cm.ksmobile.com',
#  'www.youtube.com',
#  'www.youtube-nocookie.com',
#  'yt3.ggpht.com',
#  'suggestqueries.google.com',
#  'i.ytimg.com',
#  'r11---sn-q0c7dn7s.googlevideo.com',
#  'googleads.g.doubleclick.net',
#  's.youtube.com',
#  'r5---sn-cg07luee.googlevideo.com',
#  'r6---sn-a5mekm7k.googlevideo.com',
#  'r13---sn-q0c7dn7z.googlevideo.com',
#  'r4---sn-cg07luee.googlevideo.com',
#  'r10---sn-q0c7dn7e.googlevideo.com',
#  'e9.whatsapp.net',
#  '2.100.252.173.in-addr.arpa',
#  '2.android.pool.ntp.org',
#  'e1.whatsapp.net',
#  'lh3.ggpht.com',
#  'lh6.ggpht.com',
#  'lh5.ggpht.com',
#  'lh4.ggpht.com',
#  'developers.facebook.com',
#  'dsn2.d.skype.net',
#  '65524.0.3.5.20703.rst15.r.skype.net',
#  'az361816.vo.msecnd.net',
#  'conn.skype.com',
#  'dr.skype.net',
#  'm.hotmail.com',
#  'dub403-m.hotmail.com',
#  'blufiles.storage.msn.com',
#  'bn1304files.storage.live.com',
#  'sn2files.storage.live.com',
#  'dm2306files.storage.live.com',
#  'bn1files.storage.msn.com',
#  'bn1303files.storage.live.com',
#  'blufiles.storage.live.com',
#  'dm1files.storage.live.com',
#  'by3302files.storage.live.com',
#  'byfiles.storage.msn.com',
#  'dm2304files.storage.live.com',
#  'dm2301files.storage.live.com',
#  'sn3302files.storage.live.com',
#  'by3301files.storage.live.com',
#  'bl3302files.storage.live.com',
#  'bn1305files.storage.live.com',
#  'bn1301files.storage.live.com',
#  'skslm.swiftkey.net',
#  's3.amazonaws.com',
#  'e5.whatsapp.net',
#  '13.156.220.66.in-addr.arpa',
#  'www.evernote.com',
#  'mmi128.whatsapp.net',
#  'b-api.facebook.com',
#  'fbcdn-sphotos-e-a.akamaihd.net',
#  'fbstatic-a.akamaihd.net',
#  'fbcdn-sphotos-b-a.akamaihd.net',
#  'fbcdn-vthumb-a.akamaihd.net',
#  'fbcdn-sphotos-c-a.akamaihd.net',
#  'fbcdn-sphotos-a-a.akamaihd.net',
#  'fbcdn-sphotos-h-a.akamaihd.net',
#  'accounts.youtube.com',
#  'www.google.ie',
#  'www.one.co.il',
#  'pro.hit.gemius.pl',
#  'images.one.co.il',
#  'owwhnxbn',
#  'kdutclsbcc',
#  'haacnxxvcn',
#  'c2.zedo.com',
#  'tags.crwdcntrl.net',
#  'z1.zedo.com',
#  'ads.one.co.il',
#  'm.one.co.il',
#  'svc.one.co.il',
#  'ad.doubleclick.net',
#  'adclick.g.doubleclick.net',
#  'tpc.googlesyndication.com',
#  'm.winner.co.il',
#  'wow.one.co.il',
#  'xads.zedo.com',
#  'playlist.one.co.il',
#  'ls.hit.gemius.pl',
#  'google-cm.p.veruta.com',
#  'x.bidswitch.net',
#  'bcp.crwdcntrl.net',
#  'lotame.nexac.com',
#  'ads.yahoo.com',
#  'd.turn.com',
#  'tacoda.at.atwola.com',
#  'tags.bluekai.com',
#  'idsync.rlcdn.com',
#  'pixel.mathtag.com',
#  'adadvisor.net',
#  'i.w55c.net',
#  'ckm-m.xp1.ru4.com',
#  'rtd.tubemogul.com',
#  'sync.mathtag.com',
#  'global.ib-ibi.com',
#  'segments.adap.tv',
#  'ib.mookie1.com',
#  'rc.rlcdn.com',
#  'epiv.cardlytics.com',
#  'segments.adaptv.advertising.com',
#  'ibeu2.mookie1.com',
#  'segments.wt-data.com',
#  'a.collective-media.net',
#  'loadm.exelator.com',
#  'match.adsrvr.org',
#  'ev.ib-ibi.com',
#  'ak1.abmr.net',
#  'jwpltx.com',
#  'b3.mookie1.com',
#  'uav.tidaltv.com',
#  'dpm.demdex.net',
#  'p.univide.com',
#  'd.xp1.ru4.com',
#  'ib.adnxs.com',
#  'analytics.twitter.com',
#  'pixel.tapad.com',
#  'sync.tidaltv.com',
#  'um.simpli.fi',
#  'dps.bing.com',
#  'www.pricegrabber.com',
#  'cm.eyereturn.com',
#  'match.rundsp.com',
#  'apiservices.krxd.net',
#  'secure.adnxs.com',
#  'www.wtp101.com',
#  'd.agkn.com',
#  'ds.reson8.com',
#  'rp.gwallet.com',
#  'su.addthis.com',
#  'lrpush.apxlv.com',
#  'dt.scanscout.com',
#  'bs.serving-sys.com',
#  'sync.graph.bluecava.com',
#  'dt.videohub.tv',
#  'cms.analytics.yahoo.com',
#  'tap.rubiconproject.com',
#  'api.bizographics.com',
#  'track.eyeviewads.com',
#  'magnetic.t.domdex.com',
#  't4.liverail.com',
#  'p.d41.co',
#  'vox-static.liverail.com',
#  'beam.hlserve.com',
#  'mpp.vindicosuite.com',
#  'cmi.netseer.com',
#  'track2.securedvisit.com',
#  'pixel.sitescout.com',
#  'direct.tekblue.net',
#  'c.jsrdn.com',
#  'cs.tekblue.net',
#  'seg.sharethis.com',
#  'ardrone.swoop.com',
#  'lrp.mxptint.net',
#  'ml314.com',
#  'pippio.com',
#  'cm.adgrx.com',
#  'us-u.openx.net',
#  't.mookie1.com',
#  'p.rfihub.com',
#  'action.media6degrees.com',
#  'log.dmtry.com',
#  'pixel.jumptap.com',
#  'lrcm.amgdgt.com',
#  'servedby.flashtalking.com',
#  's.thebrighttag.com',
#  'b.scorecardresearch.com',
#  'px.owneriq.net',
#  'b.videoamp.com',
#  't1.tentaculos.net',
#  'e2.whatsapp.net',
#  'trc.taboola.com',
#  'hurterkranach.net',
#  'clients1.google.com',
#  'aw.dw.impact-ad.jp',
#  'cc.chango.com',
#  'tag.crsspxl.com',
#  'lion.collect.mentad.com',
#  'pxl.connexity.net',
#  'pixels.sbal4kp.com',
#  'sync.adap.tv',
#  'p.raasnet.com',
#  'tapestry.tapad.com',
#  'sync.adaptv.advertising.com',
#  'pix.btrll.com',
#  'e.nexac.com',
#  'r.casalemedia.com',
#  'tags.w55c.net',
#  'liveramp2waycm-atl.netmng.com',
#  'dc.optimahub.com',
#  'ad.atdmt.com',
#  'widgets.outbrain.com',
#  'one.co.il',
#  'sites.one.co.il',
#  'advancedmedia.co.il',
#  'fun.one.co.il',
#  'isa.one.co.il',
#  'isf.one.co.il',
#  'i.ctnsnet.com',
#  'c1.rfihub.net',
#  'pix04.revsci.net',
#  'pixel.rubiconproject.com',
#  'image2.pubmatic.com',
#  'dsum.casalemedia.com',
#  'soma.smaato.net',
#  'sync.search.spotxchange.com',
#  'r.nexac.com',
#  'cdn.spotxchange.com',
#  'fota.cyngn.com',
#  'themes.cyngn.com',
#  'iclientgw.alipay.com',
#  'api.pinterest.com',
#  'mobile.bankleumi.co.il',
#  'trade.bankleumi.co.il',
#  'fbcdn-video-h-a.akamaihd.net',
#  'connect.facebook.net',
#  'externalapi.bizportal.co.il',
#  'odb.outbrain.com',
#  'images.outbrain.com',
#  'log.outbrain.com',
#  'ftp5.bizportal.co.il',
#  'fonts.googleapis.com',
#  'fonts.gstatic.com',
#  'rotter.net',
#  '5f816b34.api.splkmobile.com',
#  '57.182.241.54.in-addr.arpa',
#  'e.admob.com',
#  '152.52.203.199.in-addr.arpa',
#  'kbdfd.ksmobile.com',
#  'img.cm.ksmobile.com',
#  'mobidcs.ebay.com',
#  'svcs.ebay.com',
#  'history.google.com',
#  'dm.lookout.com',
#  'e3.whatsapp.net',
#  'fbcdn-video-m-a.akamaihd.net',
#  'fbcdn-video-o-a.akamaihd.net',
#  'scontent-cdg.xx.fbcdn.net',
#  'flqzhmsvrocw',
#  'focpxcad',
#  'qedwoaf',
#  '119.152.241.54.in-addr.arpa',
#  'picasaweb.google.com',
#  'cms.utag.ksmobile.com',
#  'fbcdn-video-c-a.akamaihd.net',
#  'lnubkgrv',
#  'zdzjtsuwxniywmq',
#  'ruzmvyimj',
#  '76.150.219.54.in-addr.arpa',
#  'zserver.hola.org',
#  'www.cdn.viber.com',
#  'aloha.viber.com',
#  'm.accuweather.com',
#  'vortex.accuweather.com',
#  'sirocco.accuweather.com',
#  'ad.crwdcntrl.net',
#  'appworld.blackberry.com',
#  'itunes.apple.com',
#  't2.gstatic.com',
#  'www.accuweather.com',
#  'www.windowsphone.com',
#  'gqduaax',
#  'tnmzqtnfbhrvz',
#  'hbuvregrrbhmcys',
#  'js-agent.newrelic.com',
#  'bam.nr-data.net',
#  'zudqkdqztp',
#  'pbczzlctc',
#  'tklcvozo',
#  'hdjywle',
#  'wpjcyfleoremmib',
#  'qtdkijdpob',
#  '136.178.215.54.in-addr.arpa',
#  'uzzasnvzek',
#  'hsskaxhlsjcqtwl',
#  'zpdtsvest',
#  'e6.whatsapp.net',
#  'fbcdn-dragon-a.akamaihd.net',
#  'oackficmwne',
#  'qsdlsrqzvac',
#  'kkzpnyfwtrq',
#  '137.60.193.54.in-addr.arpa',
#  'fbcdn-video-i-a.akamaihd.net',
#  'api-read.facebook.com',
#  'funnny.net',
#  'widgets.amung.us',
#  't.dtscout.com',
#  's.ytimg.com',
#  'whos.amung.us',
#  'static.ak.facebook.com',
#  's-static.ak.facebook.com',
#  'i.simpli.fi',
#  'cdn.tynt.com',
#  'ce.lijit.com',
#  'bh.contextweb.com',
#  'm.facebook.com',
#  'fbcdn-photos-h-a.akamaihd.net',
#  'xtrapath3.izatcloud.net',
#  'rt-il.waze.com',
#  'waze-tiles-legacy-cdn.waze.com',
#  'ctiles.world.waze.com',
#  'social.waze.co.il',
#  'ttsgw.world.waze.com',
#  'roadshields.waze.com',
#  'cres.waze.com',
#  'il-advil.waze.com',
#  'maps.googleapis.com',
#  'd1oiazdc2hzjcz.cloudfront.net',
#  'venue-image.waze.com',
#  'bytfvrhke',
#  'lugxrworcdemen',
#  'sgbwcrl',
#  '58.154.219.54.in-addr.arpa',
#  'e12.whatsapp.net',
#  'xtrapath1.izatcloud.net',
#  'was.waze.co.il',
#  'whitepages.com',
#  'www.callvu.net',
#  'callvu.net',
#  'www.globes.co.il',
#  'ad.ajillionmax.com',
#  'e.crashlytics.com',
#  'cdn.ajillionmax.com',
#  'reports.crashlytics.com',
#  'live.sekindo.com',
#  'images.globes.co.il',
#  'track.mobiyield.com',
#  'mead-production.s3.amazonaws.com',
#  'query.yahooapis.com',
#  'zgorwxrklza',
#  'qivdjcv',
#  'iaudmmjowgjx',
#  'encrypted-tbn0.gstatic.com',
#  'xcbdnalmttdk',
#  'ixwadutadl',
#  'drcqglk',
#  'zzfgrajuw',
#  'uilejidohnvbl',
#  'rnhectsfkf',
#  'iweovaykyz',
#  'jsbtaciahed',
#  'odallxtvrov',
#  'e8.whatsapp.net',
#  'dns-test1.hola.org',
#  'http-test1.hola.org',
#  'cdnjs.cloudflare.com',
#  'fbcdn-video-e-a.akamaihd.net',
#  'app-api.ted.com',
#  'kxlhosrjjya',
#  'ozsminmpd',
#  'hazizsdt',
#  'id.google.ie',
#  'id.google.co.il',
#  'mangulator.com',
#  's0.wp.com',
#  'stats.wp.com',
#  '0.gravatar.com',
#  '1.gravatar.com',
#  'jetpack.wordpress.com',
#  '2.gravatar.com',
#  'plus.google.com',
#  'public-api.wordpress.com',
#  's1.wp.com',
#  's2.wp.com',
#  'twitter.com',
#  'i1.wp.com',
#  'www.mangulator.com',
#  'he.wordpress.org',
#  'pixel.wp.com',
#  'gravatar.com',
#  'ota.cloudfront.lookout.com',
#  'whisperpush.cyanogenmod.org',
#  'e10.whatsapp.net',
#  'mmi234.whatsapp.net',
#  'fbcdn-video-d-a.akamaihd.net',
#  'bit.ly',
#  'www.inn.co.il',
#  'a7.org',
#  'info.a7.org',
#  'n2.a7.org',
#  '2.inn.co.il',
#  'cdn.engine.adsupply.com',
#  'fb.mod.gov.il',
#  'ner.izkor.mod.gov.il',
#  'www.izkor.gov.il',
#  'swiftkey-sync-production.touchtype-fluency.com',
#  'oyzvpogd',
#  'ltqhzwsbuu',
#  'bzwehcjfut',
#  'lgtzdqxunoy',
#  'eqzjibl',
#  'ipmywwexvlwj',
#  'ekmldsjixsjrxs',
#  'awqqepzrpc',
#  'cfguwqbt',
#  '2.93.13.31.in-addr.arpa',
#  'perr.hola.org',
#  'mmi204.whatsapp.net',
#  'router.bittorrent.com',
#  'router.utorrent.com',
#  'dht.transmissionbt.com',
#  'dht.aelitis.com',
#  'r3---sn-q0c7dn7k.googlevideo.com',
#  'r3---sn-cg07luer.googlevideo.com',
#  'r15---sn-q0c7dn76.googlevideo.com',
#  'r6---sn-cg07lues.googlevideo.com',
#  'r16---sn-q0c7dn7k.googlevideo.com',
#  'viber-content.s3.amazonaws.com',
#  'r16---sn-q0c7dn7e.googlevideo.com',
#  'r9---sn-q0c7dn7y.googlevideo.com',
#  'r7---sn-cg07luek.googlevideo.com',
#  'r13---sn-q0c7dn7e.googlevideo.com',
#  'r4---sn-cg07lues.googlevideo.com',
#  'r1---sn-q0c7dn76.googlevideo.com',
#  'fbcdn-video-p-a.akamaihd.net',
#  'youtu.be',
#  'm.youtube.com',
#  'gg.google.com',
#  'r10---sn-q0c7dn76.googlevideo.com',
#  'r8---sn-cg07lue6.googlevideo.com',
#  'r6---sn-a5m7zu7z.googlevideo.com',
#  'cmdump.upload.duba.net',
#  'm.c.lnkd.licdn.com',
#  'media.licdn.com',
#  'backup.lookout.com',
#  'fbcdn-creative-a.akamaihd.net',
#  'emast001pgwp.saas.hp.com',
#  'data.hulyo.co.il',
#  'catalogs.hulyo.co.il',
#  'd2ymkapos72i.cloudfront.net',
#  'api.terapush.com',
#  'm.booking.com',
#  'q-ec.bstatic.com',
#  'r-ec.bstatic.com',
#  'bstatic.com',
#  'tags.tiqcdn.com',
#  'ipango.itip.co.il',
#  'combine.urbanairship.com',
#  'www.mcpsmartphonews.4500.co.il',
#  'lh4.googleusercontent.com',
#  'external.xx.fbcdn.net',
#  'fmqxavyjudkljh',
#  'tyuhkgyeje',
#  'mpepsmqs',
#  't0.gstatic.com',
#  'tixujjlimntxr',
#  'yxdmwktfvygvxk',
#  'kipbzwoutpr',
#  't3.gstatic.com',
#  'www.nikib.co.il',
#  'ad.vast.co.il',
#  's7.addthis.com',
#  'scontent.cdninstagram.com',
#  'feeds.feedburner.com',
#  'platform.twitter.com',
#  'nikib.co.il',
#  'instagram.com',
#  'n.sendmsg.co.il',
#  'www.spd.co.il',
#  'www.fatmeir.com',
#  'www.sekindo.com',
#  'www.eplace.co.il',
#  'www.tapuz.co.il',
#  'api-public.addthis.com',
#  'm.addthis.com',
#  'm.addthisedge.com',
#  'nikib.tempurl.co.il',
#  't1.gstatic.com',
#  'rcs.mako.co.il',
#  'mobile.mako.co.il',
#  'www.mako.co.il',
#  'img.mako.co.il',
#  'st.dynamicyield.com',
#  'ddrn6tjst80qg.cloudfront.net',
#  'static.dynamicyield.com',
#  'px.dynamicyield.com',
#  'sdc.mako.co.il',
#  'kanbonim.mako.co.il',
#  'fashionforward.mako.co.il',
#  'www.auto.co.il',
#  'stats.mako.co.il',
#  'fbcdn-static-b-a.akamaihd.net',
#  'r5---sn-q0c7dn7d.googlevideo.com',
#  'r9---sn-q0c7dn7k.googlevideo.com',
#  'r5---sn-5hn7su7s.googlevideo.com',
#  'r15---sn-q0c7dn7e.googlevideo.com',
#  'www.baidu.com',
#  'www.qq.com',
#  'loopme.me',
#  'i.loopme.me',
#  'e4.whatsapp.net',
#  'bddoc.ksmobile.net',
#  'e14.whatsapp.net',
#  'swiftkey-android.iris.touchtype-fluency.com',
#  'secure-uat-dpr.imrworldwide.com',
#  '1.90.13.31.in-addr.arpa',
#  'fbcdn-video-g-a.akamaihd.net',
#  'www.haaretz.co.il',
#  'ajax.googleapis.com',
#  'linicom.co.il',
#  'code.jquery.com',
#  'themes.googleusercontent.com',
#  'piwik.themarker.com',
#  'ad.turn.com',
#  'cdn.turn.com',
#  's1.2mdn.net',
#  'ping.chartbeat.net',
#  'e7.whatsapp.net',
#  'uoovuirmd',
#  'mqtpxlzjxc',
#  'ztufbtrocbmozl',
#  'lt.andomedia.com',
#  'audio-dc6-t1-2-v4v6.pandora.com',
#  'cont-ch1-2.pandora.com',
#  'tuner.pandora.com',
#  'www.pandora.com',
#  'cont-1.p-cdn.com',
#  'cont-ch1-1.pandora.com',
#  'cont-sv5-3.pandora.com',
#  'lnqhrrsgmpmo',
#  'mvrmxhbcege',
#  'uklrwjrnt',
#  'mmi639.whatsapp.net',
#  'mmi648.whatsapp.net',
#  'mmi634.whatsapp.net',
#  'mmi625.whatsapp.net',
#  'cont-sjl-2.pandora.com',
#  'api.aliexpress.com',
#  'stats.pandora.com',
#  'kxfmmjndavfvyd',
#  'zmhjeya',
#  'dvsstmjeghbpmu',
#  'besttv1.cdn.it.best-tv.com',
#  'metrics.brightcove.com',
#  'phpproxy.advsnx.net',
#  'lb.advsnx.net',
#  'ci4.googleusercontent.com',
#  'ci6.googleusercontent.com',
#  'cm.gcm.ksmobile.com',
#  'mmi636.whatsapp.net',
#  'mmi107.whatsapp.net',
#  'mmi624.whatsapp.net',
#  'r1---sn-q0c7dn7y.googlevideo.com',
#  'mmi603.whatsapp.net',
#  'r16---sn-q0c7dn7d.googlevideo.com',
#  'r3---sn-cg07luez.googlevideo.com',
#  'mmi215.whatsapp.net',
#  'mmi646.whatsapp.net',
#  'mmi637.whatsapp.net',
#  'e11.whatsapp.net',
#  'mmi629.whatsapp.net',
#  'mmv283.whatsapp.net',
#  'mmi208.whatsapp.net',
#  'mmv604.whatsapp.net',
#  'mmi608.whatsapp.net',
#  'js.casalemedia.com',
#  'as.casalemedia.com',
#  'cdn.komoona.com',
#  'stat.komoona.com',
#  'a.komoona.com',
#  'ads.pubmatic.com',
#  's.komoona.com',
#  'geo.smaato.net',
#  'showads.pubmatic.com',
#  'choices.truste.com',
#  'aktrack.pubmatic.com',
#  'image4.pubmatic.com',
#  'kbd2.kpns.ijinshan.com',
#  'easy.co.il',
#  'commondatastorage.googleapis.com',
#  'ira.easy.co.il',
#  'werdarom.co.il',
#  'www.mdigital.co.il',
#  'rlwwtnpb',
#  'zoxboldftav',
#  'loxetbwseuvw',
#  'www.israelpost.co.il',
#  'gr.pn',
#  'www.groupon.co.il',
#  'm.groupon.co.il',
#  'static.il.groupon-content.net',
#  'www.googletagmanager.com',
#  's3-eu-west-1.amazonaws.com',
#  'www.zooma.co.il',
#  'zooma.co.il',
#  'cts.channelintelligence.com',
#  'static.groupon.co.il',
#  'tracking.groupon.com',
#  'passets-cdn.pinterest.com',
#  'trk.pinterest.com',
#  'media-cache-ec0.pinimg.com',
#  'media-cache-ak0.pinimg.com',
#  'www.myparadissi.com',
#  'www.blogger.com',
#  'pipdigz.co.uk',
#  'apis.google.com',
#  '2.bp.blogspot.com',
#  '1.bp.blogspot.com',
#  'img1.blogblog.com',
#  '3.bp.blogspot.com',
#  'www.statcounter.com',
#  'c.statcounter.com',
#  'img2.blogblog.com',
#  'oauth.googleusercontent.com',
#  'mmv669.whatsapp.net',
#  'fbcdn-video-f-a.akamaihd.net',
#  'www.boredpanda.com',
#  'static.boredpanda.com',
#  'cdn.socket.io',
#  'assets.pinterest.com',
#  'us-ads.openx.net',
#  'platform.stumbleupon.com',
#  's3.buysellads.com',
#  'go.realvu.net',
#  'badge.stumbleupon.com',
#  'u.openx.net',
#  'log.pinterest.com',
#  'cdn.stumble-upon.com',
#  'uk-ads.openx.net',
#  'eu-u.openx.net',
#  'tag.contextweb.com',
#  'ads.contextweb.com',
#  'delivery.vidible.tv',
#  'euwfb.adsrvr.org',
#  'trk.vidible.tv',
#  'tr.contextweb.com',
#  'pixel.quantserve.com',
#  'cdn.vidible.tv',
#  'z.on.aol.com',
#  'ad4.liverail.com',
#  'builds.cyngn.com',
#  'apkquery.ksmobile.net',
#  'cm.utag.ksmobile.com',
#  'appintel.mobilethreat.net',
#  'safebrowsing.google.com',
#  'apkdetail.ksmobile.net',
#  'cm.adkmob.com',
#  'dtlabs.bgu.ac.il',
#  'mmi640.whatsapp.net',
#  'mmi106.whatsapp.net',
#  'mmi615.whatsapp.net',
#  'mmi219.whatsapp.net',
#  'podium.augmentad.net',
#  'msc.walla.co.il',
#  'img2.globes.co.il',
#  'm.globes.co.il',
#  'k.co.il',
#  'prod-15-ireland.s3-website-eu-west-1.amazonaws.com',
#  'akamai.advsnx.net',
#  'prod-15-ireland.s3.amazonaws.com',
#  'www.cast-tv.biz',
#  'il28.cast-tv.com',
#  'static.chartbeat.com',
#  'banners.advsnx.net',
#  'statistik-gallup.net',
#  'msc.wcdn.co.il',
#  'www.yl-invest.co.il',
#  'support.daronet.com',
#  'mms886.whatsapp.net',
#  'events.bgu.co.il',
#  'www.bgu.co.il',
#  'ashan.bgu.co.il',
#  'baraka.bgu.co.il',
#  'cool.bgu.co.il',
#  'forum.bgu.co.il',
#  'fringe.bgu.co.il',
#  'giza.bgu.co.il',
#  'studate.bgu.co.il',
#  'uza.bgu.co.il',
#  'yeda.bgu.co.il',
#  'www.studate.co.il',
#  'ptjqlcyaej',
#  'glcdkabmnbm',
#  'ohvvwovaozk',
#  'www.halutz33.co.il',
#  'www.calcalist.co.il',
#  'm.calcalist.co.il',
#  'server.cappsool.com',
#  'images1.calcalist.co.il',
#  'm.smartube.mobi',
#  'www.relevanti.com',
#  'wcdn.zoomanalytics.co',
#  'mmi620.whatsapp.net',
#  's0.2mdn.net',
#  'uglsunvhtlro',
#  'dieorrfsrtdjtwb',
#  'ggyhwbroreswo',
#  'mmi631.whatsapp.net',
#  'jdkmhgbiwogzbg',
#  'suojpzgrojurk',
#  'bvrqmsz',
#  'jaqygbajazqkfvo',
#  'qgslajvhxdnx',
#  'agfsxqal',
#  'mmv210.whatsapp.net',
#  'partner.googleadservices.com',
#  'apicdn.zoomanalytics.co',
#  'cdn1.zoomanalytics.co',
#  'sherut.bezeqint.net',
#  'm.maariv.co.il',
#  'www.jpost.com',
#  'www.maariv.co.il',
#  'maarivonline.disqus.com',
#  'a.disquscdn.com',
#  'disqus.com',
#  'zoomanalytics.co',
#  'd2z0twhaibasxg.cloudfront.net',
#  'referrer.disqus.com',
#  'glitter.services.disqus.com',
#  'realtime.services.disqus.com',
#  'ads.dynamicyield.com',
#  'www.chokoladsrv.net',
#  'dmp.adform.net',
#  'a01.korrelate.net',
#  'hbwap.bankleumi.co.il',
#  'stats.justad.mobi',
#  'media.justad.mobi',
#  'sdk.justad.mobi',
#  '104.60.193.54.in-addr.arpa',
#  'mms888.whatsapp.net',
#  'mmi130.whatsapp.net',
#  'wlpslpul',
#  'kgjtdbjhe',
#  'qntalpyexyganq',
#  'keymaster.lookout.com',
#  'accounts.google.co.il',
#  'accounts.google.ie',
#  'r16---sn-q0c7dn7e.gvt1.com',
#  'r1---sn-q0c7dn76.gvt1.com',
#  'r18---sn-q0c7dn7z.gvt1.com',
#  'logger.instagram.com',
#  'ocyejahl',
#  'qfobfquyrtvx',
#  'amfdbuteg',
#  'trailer.web-view.net',
#  'cdn-media.web-view.net',
#  'mms887.whatsapp.net',
#  'cp.responder.co.il',
#  'www.b7t.co.il',
#  'tickets.b7t.co.il',
#  'act-b7.co.il',
#  'b7t.co.il',
#  'www.shaked-adv.com',
#  'xtrapath2.izatcloud.net',
#  'gapi.waze.com',
#  'idniuujd',
#  'dvhaykyiatzzvq',
#  'zoudjnobotec',
#  'discovery.lookout.com',
#  'www.jobmaster.co.il',
#  'ezwgnmi',
#  'pwronfqotybv',
#  'mavmxpxmabxsar',
#  'mmi628.whatsapp.net',
#  'prod.payboxapp.com',
#  'mmv226.whatsapp.net',
#  'fbcdn-video-j-a.akamaihd.net',
#  'fbcdn-video-a-a.akamaihd.net',
#  'update.evernote.com',
#  'lizyecad',
#  'vdotloixoynhi',
#  'ugiojuxcra',
#  'bitcoinity.org',
#  'static.bitcoinity.org',
#  'bitcointalk.org',
#  'wallofcoins.com',
#  'www.reddit.com',
#  'wedbqwqr',
#  'egueufukfgwhfak',
#  'gcowfzgvajzsxpz',
#  'qivyorsoqq',
#  'ontmolxritob',
#  'enlncyjbuiyg',
#  'www.walla.co.il',
#  'fus.walla.co.il',
#  'isc.wcdn.co.il',
#  'xwbe.wcdn.co.il',
#  'x.walla.co.il',
#  'ws.walla.co.il',
#  'i.walla.co.il',
#  'a.walla.co.il',
#  'xlpkylvhscqjo',
#  'jrxxcuozw',
#  'pesgogbaowwox',
#  'dsn1.d.skype.net',
#  '65524.0.3.5.20703.rst1.r.skype.net',
#  'drtest.skype-cr.akadns.net',
#  'bonimbayit.us7.list-manage1.com',
#  'bonimbayit.co.il',
#  'maxcdn.bootstrapcdn.com',
#  '4.bp.blogspot.com',
#  'www.easypolls.net',
#  'en.wikipedia.org',
#  'widget.websta.me',
#  'www.brandtech.com',
#  'www.centralvacuumstores.com',
#  'bonimbayit.blogspot.com',
#  'ghost-bonim.disqus.com',
#  'cyrbbippcxgksyd',
#  'tpuypdcgxtpfs',
#  'eqlcxpuelkemcmy',
#  'websta.me',
#  'docs.disqus.com',
#  'facebook.com',
#  'www.murvey.com',
#  'www.objectplanet.com',
#  'faviconist.com',
#  'help.disqus.com',
#  'disq.us',
#  'www.surveymonkey.com',
#  'hmcznebgirs',
#  'ujmrcxvruqpp',
#  'silnhjzc',
#  'mms877.whatsapp.net',
#  'r5---sn-q0c7dn7l.gvt1.com',
#  'r13---sn-q0c7dn7e.gvt1.com',
#  'r1---sn-q0c7dn7d.gvt1.com',
#  's-media-cache-ak0.pinimg.com',
#  'r13---sn-q0c7dn7k.gvt1.com',
#  'r2---sn-q0c7dn7k.gvt1.com',
#  'r11---sn-q0c7dn7d.gvt1.com',
#  'tszsvhh',
#  'dmnhqcqfweauu',
#  'oiywtso',
#  'mmi225.whatsapp.net',
#  'mmi240.whatsapp.net',
#  'mmi201.whatsapp.net',
#  'mmi205.whatsapp.net',
#  'nfbnjuwd',
#  'ahiwnnvdb',
#  'tqxfkhoxja',
#  'openx.alljobs.co.il',
#  'd296wykt099k0b.cloudfront.net',
#  'fhwsijpq',
#  'nyjfxth',
#  'mpwvymmyibbw',
#  'geo0.ggpht.com',
#  'mmi236.whatsapp.net',
#  'mms890.whatsapp.net',
#  'mmv295.whatsapp.net',
#  'tabzmgeymmtido',
#  'drotpeirgqpo',
#  'jdydomsbrpzme',
#  'he.m.wikipedia.org',
#  'bits.wikimedia.org',
#  'upload.wikimedia.org',
#  'mmi622.whatsapp.net',
#  'mmi218.whatsapp.net',
#  'tfhjszxgemggcg',
#  'uoewhjxhqacxjr',
#  'bvswgruttenky',
#  'mmi239.whatsapp.net',
#  'mpg.leumi-card.co.il',
#  'services.leumi-card.co.il',
#  'www.leumi-card.co.il',
#  'api.raygun.io',
#  '195.194.18.50.in-addr.arpa',
#  '199.160.215.54.in-addr.arpa',
#  'gallery.mailchimp.com',
#  'www.li-lo.co.il',
#  'ocyizusodpe',
#  'sbzwpuyhm',
#  'etmkbjumddgslrq',
#  'mplqvxztjcri',
#  'lhmzdrm',
#  'kgsxlxgg',
#  'ad.yieldmanager.com',
#  'encrypted-tbn2.gstatic.com',
#  'r7---sn-oxu8pnpvo-ua8e.gvt1.com',
#  'qjqxymra',
#  ...]

# %%
common_domains = {}
for domain in known_domains:
    common_domains[domain] = len([user for user in domains_per_user if domain in user])

common_domains_below_threshold = {key: value for key, value in common_domains.items() if
                                  value <= DOMAIN_COUNT_THRESHOLD}
common_domains_without_dot = {key: value for key, value in common_domains.items() if '.' not in key}
common_domains_above_threshold = {key: value for key, value in common_domains.items() if value > 1}
suspicious_domains = set(common_domains_without_dot.keys()) & set(common_domains_below_threshold.keys())
valid_domains = set(common_domains.keys()) - suspicious_domains

print("Number of suspicious domains - with less then {} usage and without dot: {}. Exmaples:\n{}\n"
      .format(DOMAIN_COUNT_THRESHOLD, len(suspicious_domains), list(suspicious_domains)[:5]))
# Out:
# Number of suspicious domains - with less then 1 usage and without dot: 35236. Exmaples:
# ['hjijplvcblqun', 'tdwiqlwplrjqj', 'ujckfbdepynvpxk', 'seuyrwcems', 'sezuecy']

# %%
def get_domain_usage_count():
    domains_usage_count = {}
    all_packets = users_data[0].copy()
    for user in users_data[1:]:
        relevant_user_packet = user[:LEARNING_CHUNKS * NUMBER_OF_QUERIES_EACH_CHUNK] # comment this if you want to use queries from all data
        all_packets = all_packets.append(relevant_user_packet, ignore_index=True)

    all_relevant_packets = all_packets
    all_relevant_domains = all_relevant_packets['dns.qry.name'].value_counts().index
    domains_usage_in_relevant_packets = all_relevant_packets['dns.qry.name'].value_counts()

    if True:
        for domain in valid_domains:
            domains_usage_count[domain] = 0
            if domain in all_relevant_domains:
                domains_usage_count[domain] += int(domains_usage_in_relevant_packets[domain])

        with open("./data/domains_usage_count_only_train_data.json", 'w') as h:
            json.dump(domains_usage_count, h)
    else:
        with open("./data/domains_usage_count.json", 'r') as h:
            domains_usage_count = json.load(h)
    
    return domains_usage_count

# %%
domains_usage_count = get_domain_usage_count()
domains_usage_count
# Out:
# {'us.my.alibaba.com': 0,
#  'www1063.mdotm.com': 0,
#  'r6---sn-q4f7dm7l.googlevideo.com': 0,
#  'mmi115.whatsapp.net': 4,
#  'chatdepot.twitch.tv': 2,
#  'mekomit.co.il': 4,
#  'psapp-start.dl.playstation.net': 2,
#  '65524.0.3.5.20703.rst15.r.skype.net': 4,
#  'p4-dghageiot3y4m-5jgjgszwv6cyg5na-482792-i1-v6exp3-ds.metric.gstatic.com': 0,
#  'seretil.me': 2,
#  'www.middleeasteye.net': 0,
#  'e13.whatsapp.net': 875,
#  'p4-cqaofin4hk7p6-chkef5svkhbn2kl6-275209-i1-v6exp3-v4.metric.gstatic.com': 0,
#  'cdn-1.convertexperiments.com': 6,
#  'cdn1.clkmon.com': 2,
#  'app.sketch.sc.sonymobile.com': 0,
#  'igy-il.disqus.com': 0,
#  'mmi218.whatsapp.net': 30,
#  'videos-b-16.ak.instagram.com': 18,
#  'r20---sn-q0c7dn7k.gvt1.com': 0,
#  'r4---sn-q0c7dn7k.googlevideo.com': 4,
#  's.ad132m.com': 2,
#  '136.178.215.54.in-addr.arpa': 110,
#  'mmv283.whatsapp.net': 4,
#  'www.underwar.co.il': 0,
#  'mgid.com': 2,
#  'justwhookid.disqus.com': 0,
#  'www.fisheye.co.il': 2,
#  'www.maslulim-israel.co.il': 0,
#  'tapestry.tapad.com': 14,
#  'load.passionfruitads.com': 0,
#  'p4-bnaiwa6hzndlg-txx4r5tsa4ljnx7d-962642-s1-v6exp3-v4.metric.gstatic.com': 0,
#  'p-behacdn.ksmobile.net': 197,
#  'fogeli.co.il': 4,
#  'xwbe.wcdn.co.il': 221,
#  'r1---sn-q0c7dn7s.googlevideo.com': 2,
#  'bank-5.ads.mp.mydas.mobi': 0,
#  'static.apester.com': 10,
#  'wms-na.amazon-adsystem.com': 0,
#  'heritage-key.com': 2,
#  'web.archive.org': 6,
#  'matterdome.com': 0,
#  'videos-c-17.ak.instagram.com': 0,
#  'img100-288.xvideos.com': 0,
#  'rum-collector.pingdom.net': 0,
#  'cdn-media.web-view.net': 14,
#  'cdn.skum.eamobile.com': 42,
#  'd9hhrg4mnvzow.cloudfront.net': 0,
#  'evernote-a.akamaihd.net': 4,
#  '191.112.194.173.in-addr.arpa': 8,
#  '32d1d3b9c.se': 4,
#  'net.nana10.co.il': 2,
#  'i.s-microsoft.com': 0,
#  'www.mobitti.com': 4,
#  'mtalk.google.com.ac.il': 32,
#  'sportsillustrated.cnn.com': 0,
#  'img100-270.xvideos.com': 0,
#  'www.nlm.nih.gov': 2,
#  'creativework.mtv.com.au': 0,
#  'ronangelo.com': 0,
#  'wokinfo.com': 0,
#  'www2.sawlive.tv': 2,
#  'shared.mtv.com': 0,
#  'www.tinylinks.co': 4,
#  'scholar.lmgtfy.com': 2,
#  'cdn.pubexchange.com': 0,
#  'eu.dr.skype.net': 0,
#  'insight.adsrvr.org': 2,
#  'ru.aliexpress.com': 0,
#  'gp6.googleusercontent.com': 4,
#  'mmv669.whatsapp.net': 4,
#  'www.eventim.ro': 0,
#  'porn.im.36483300.2404796.x.xvideos.com': 0,
#  'www.lapidtec.co.il': 0,
#  'audience.powerlinks.com': 0,
#  'istudent.co.il': 0,
#  'mb.mtv.com': 0,
#  'maps.apple.com': 4,
#  'streamfifamatches.tv': 2,
#  'p4-cavvpbc2kbwas-qgywqmbo3fbsdofz-if-v6exp3-v4.metric.gstatic.com': 0,
#  'm.castro.com': 4,
#  'play.google.com': 232,
#  'm.soundcloud.com': 2,
#  'p.raasnet.com': 6,
#  'tracking.keywee.co': 0,
#  'ecnmedia.static-economist.com': 2,
#  'adlog.flurry.com': 6,
#  'physweb.bgu.ac.il': 0,
#  'www.viralfever.biz': 4,
#  'www.mediawiki.org': 4,
#  'p4-etywnujvmvkju-c2glnkeobnux3ral-457142-i1-v6exp3-ds.metric.gstatic.com': 0,
#  'ucbtheatre.com': 2,
#  'videos-h-10.ak.instagram.com': 0,
#  'r6---sn-q4f7dm76.googlevideo.com': 0,
#  'www.telegraph.co.uk': 16,
#  'services.picadmedia.com': 0,
#  'clients3.google.com.ac.il': 15,
#  'r7---sn-aigllm7r.googlevideo.com': 0,
#  'f328f4d4c80KGZEDHHA-nainvshw1429794561-sonar.xx.fbcdn.net': 4,
#  'www.rak.co.il': 0,
#  'p4-edud2us2qnkma-oanctsspphzpo5qo-216635-i1-v6exp3-v4.metric.gstatic.com': 0,
#  'files.bannersnack.com': 0,
#  'www.gadial.net': 0,
#  'ticktick.com': 0,
#  'web.mit.edu': 0,
#  'doctorsonly.co.il': 0,
#  's0.2mdn.net': 258,
#  'www.ezflow.com': 0,
#  'translate.google.co.il': 0,
#  'facebook.com': 18,
#  'www.beetailer.com': 0,
#  'videos-c-18.ak.instagram.com': 8,
#  'external.dmtracker.com': 2,
#  'files2.adme.ru': 0,
#  'www.taimeod.co.il': 0,
#  'www.maya-foods.com': 0,
#  'a.intsig.net': 32,
#  'r15---sn-nx57ynel.gvt1.com': 0,
#  'bl3302files.storage.live.com': 4,
#  'www.queerty.com': 0,
#  'onepush.query.yahoo.com': 0,
#  'pigment-adv.1host.co.il': 0,
#  'adoric.com': 0,
#  'images.vicomi.com': 14,
#  'api.tozelabs.com': 0,
#  'img100-215.xvideos.com': 0,
#  'wikiislam.net': 0,
#  'karaoketv.walla.co.il': 12,
#  'graphics8.nytimes.com': 2,
#  'www.mountofolives.co.il': 0,
#  'scholar.google.co.il': 0,
#  'www.mtvtix.com.au': 0,
#  'mg.yadro.ru': 0,
#  'ru.pornhub.com': 0,
#  'BAYMSGR2012808.gateway.messenger.live.com': 0,
#  'p4-fzklatb2wkgms-ryrlvu5ynwhgprqm-if-v6exp3-v4.metric.gstatic.com': 2,
#  'r6---sn-q0c7dn7k.gvt1.com': 22,
#  'physicsworld.com': 0,
#  '4798106.fls.doubleclick.net': 2,
#  'st.mycdn.me': 0,
#  'cdnbakmi.kaltura.com': 2,
#  'surprises.tango.me': 0,
#  'www.erowid.org': 2,
#  'r10---sn-q0c7dn76.gvt1.com': 4,
#  'r19---sn-q0c7dn7e.googlevideo.com': 0,
#  'aka-cdn-ns.adtechus.com': 2,
#  'dl.dc.ijinshan.com': 11,
#  'smail1009.com': 0,
#  'renderer.qmerce.com': 8,
#  'ak.sail-horizon.com': 4,
#  'fbcdn-video-h-a.akamaihd.net': 283,
#  'maps.lmgtfy.com': 2,
#  'www.czech.cz': 0,
#  'www.assoc-amazon.com': 0,
#  'grownupsgofree.kelloggs.ie': 2,
#  'sucuri.net': 0,
#  'o.twimg.com': 4,
#  'funnygig.com': 0,
#  'p4-c6wntasliuasq-7dxwgvdlrnhnykxy-104495-i1-unicast.metric.gstatic.com': 0,
#  'ib365-1851555667.us-east-1.elb.amazonaws.com': 198,
#  'bigstory.ap.org': 0,
#  'ser.adledge.com': 6,
#  'websitestat.enter-system.com': 10,
#  'dataentry.ynet.co.il': 26,
#  'affiliate-robot.com': 0,
#  '3.bp.blogspot.com': 16,
#  'www.mtv.com.au': 0,
#  'apis.google.com': 383,
#  'www.ecomtrade.co.il': 2,
#  'cmsprod.bgu.ac.il': 0,
#  'svc.m.one.co.il': 148,
#  'r3---sn-cg07luee.googlevideo.com': 0,
#  'img100-479.xvideos.com': 0,
#  'mhomesandproperty.zoopla.co.uk': 2,
#  'topics.nytimes.com': 0,
#  'cld.edg.startappservice.com': 0,
#  'adadvisor.net': 105,
#  'malcolm-prod-swarm.wbplay.com': 0,
#  'trgoals.org': 2,
#  'www.morfix.co.il': 2,
#  'ssl.google-analytics.com.bgu.ac.il': 0,
#  'image.dolphin-browser.cn': 6,
#  'p4-h3tiozzf5xpdy-avpm3inalfp7qbch-if-v6exp3-v4.metric.gstatic.com': 0,
#  'library.osu.edu': 2,
#  'ew1.api.cfpd.bdp.samsung.com': 0,
#  'funny.yo-yoo.co.il': 2,
#  'b.kavanga.ru': 0,
#  'ign-wikis.disqus.com': 2,
#  'secureir.ebaystatic.com': 2,
#  'adrta.com': 0,
#  'topmobile-app.com': 0,
#  'segs.btrll.com': 4,
#  'pixel.prfct.co': 2,
#  'r5---sn-q0c7dn7l.googlevideo.com': 2,
#  'j.mp': 8,
#  'api.asiatone.net': 0,
#  'community.wikia.com': 4,
#  'img100-414.xvideos.com': 0,
#  'my.agoda.com': 2,
#  'qos-prod-bio-dub-common-common.gos.ea.com': 14,
#  'www.orianit.edu-negev.gov.il': 2,
#  'm.studioc.co.il': 0,
#  'videos-g-17.ak.instagram.com': 4,
#  'api.github.com': 4,
#  'adplexmedia.adk2x.com': 0,
#  'img100-326.xvideos.com': 0,
#  'location.gtforge.com': 136,
#  'p4-f2s4hz2pflfja-6cmjy4p64vqeanbw-if-v6exp3-v4.metric.gstatic.com': 8,
#  'platform.twitter.com': 353,
#  'www.fullstory.com': 0,
#  'www.eater.com': 0,
#  'www.wix.com': 2,
#  'p4-bi25v2ucs6jwq-kctldf32su7u5e43-621251-i1-v6exp3-v4.metric.gstatic.com': 0,
#  'r9---sn-4g57km7z.googlevideo.com': 0,
#  'ic.3648339c.0de076.6.c3605.d.rncdn3.com': 0,
#  'dailycaller.com': 0,
#  '231.154.179.212.in-addr.arpa': 2,
#  't.mobitrk.com': 0,
#  'img100-502.xvideos.com': 0,
#  'api.tapuz.co.il': 0,
#  'r18---sn-q0c7dn7l.googlevideo.com': 8,
#  '608-events.olark.com': 0,
#  'dmp.adform.net': 38,
#  'gc.ds.duapps.com': 0,
#  'files4.adme.ru': 0,
#  'res.media.net': 2,
#  'urlauth.ksmobile.net': 1018,
#  'communabuilder.tapuz.co.il': 0,
#  'mentad.com': 0,
#  'bus.mosko.mobi': 0,
#  'mmv682.whatsapp.net': 0,
#  'img100-318.xvideos.com': 0,
#  'thepiratebay.se': 0,
#  'cdn.downdetector.com': 0,
#  'www.ew.com': 4,
#  'findnsave.sfgate.com': 0,
#  'astrateg.co.il': 0,
#  'images.starpulse.com': 2,
#  'www.tiredeal.co.il': 0,
#  'd3biamo577v4eu.cloudfront.net': 2,
#  's7.vzw.com': 0,
#  'www.arosport.co.il': 0,
#  'www.ibiblio.org': 0,
#  'front.facetz.net': 0,
#  'img100-043.xvideos.com': 0,
#  'foto-recepti.ru': 0,
#  'studate.bgu.co.il': 2,
#  'in.metamx.com': 22,
#  'ads.trafficpoizon.com': 0,
#  'i4.sndcdn.com': 0,
#  'ip-science.thomsonreuters.com': 0,
#  'ios-app-config.media-imdb.com': 0,
#  'img100-044.xvideos.com': 0,
#  'www.sitehood.co.il': 2,
#  'www.protalix.co.il': 0,
#  'nidal.tv': 2,
#  'www.osef.co.il': 0,
#  'pixel.ani-view.com': 18,
#  'maarivonline.disqus.com': 4,
#  '67.210.58.216.in-addr.arpa': 8,
#  'a899e037f69f12bff9ed41975c1be64a3.profile.waw50.cloudfront.net': 0,
#  'www.he.israelguidedog.org': 0,
#  'us16.zopim.com': 0,
#  'ic.3648339c.003979.6.c3605.d.rncdn3.com': 0,
#  'p4-fzklatb2wkgms-ryrlvu5ynwhgprqm-916124-i2-v6exp3-v4.metric.gstatic.com': 2,
#  'www.ninds.nih.gov': 0,
#  'kick.live.net.il': 0,
#  'intractability.princeton.edu': 0,
#  'www.cchr.org.il': 0,
#  'direct.revsci.net': 6,
#  'besttv2.cdn.it.best-tv.com': 10,
#  'p4-az5pjpwkzcbny-sojmdwrfcsdzgx7f-923172-i1-v6exp3-ds.metric.gstatic.com': 0,
#  'data.nba.com': 0,
#  '3-edge-chat.facebook.com': 0,
#  'browser-update.org': 4,
#  'tags.walla.co.il': 68,
#  'gamethrive.com': 6,
#  'events.frwrd.me': 0,
#  '40.media.tumblr.com': 0,
#  'api.entrance.sonymobile.com': 12,
#  'ausiellofiles.ew.com': 2,
#  'www.kelloggs.co.uk': 2,
#  'scontent-b-fra.xx.fbcdn.net': 0,
#  'dwi.d.weather.com': 2,
#  'www.lyricsfreak.com': 0,
#  'crt13.b1.cdn.co.il': 14,
#  'stats.ibtimes.co.uk': 0,
#  'cdn1.image.keezmovies.phncdn.com': 6,
#  'superitch.com': 0,
#  'www.pureexample.com': 0,
#  'beacon-eu.rubiconproject.com': 14,
#  'p4-ek72ykvaqivls-wk4yqcgz2umzvs7z-if-v6exp3-v4.metric.gstatic.com': 2,
#  'isrageo.blogspot.com': 2,
#  'scienceworld.wolfram.com': 0,
#  '65524.0.3.5.20703.rst5.r.skype.net': 0,
#  '7590.api-03.com': 0,
#  'wpcomwidgets.com': 0,
#  'mmv244.whatsapp.net': 0,
#  'xwne.wcdn.co.il': 114,
#  'papi.my6sense.com': 66,
#  'metrics.electusdigital.com': 8,
#  'www.cal-online.co.il': 0,
#  'www.sapir-aguda.co.il': 0,
#  'tickets.ticket4u.co.il': 0,
#  'us32.zopim.com': 0,
#  'www.ons.gov.uk': 2,
#  'videos-a-19.ak.instagram.com': 4,
#  'img100-701.xvideos.com': 0,
#  'dsn3.d.skype.net': 0,
#  'www.shichor.co.il': 2,
#  'egged.co.il': 0,
#  'p4-h5qszb4l4e5z6-yf4i3cd636cxm7iz-558497-i2-v6exp3-ds.metric.gstatic.com': 2,
#  'ads.medlheads.com': 8,
#  'im.36483300.56a987a.ads.a4cdn.contentabc.com': 6,
#  'koora720comchat.chatango.com': 2,
#  'eo.wikipedia.org': 0,
#  'ads.ilykefunny.com': 0,
#  'www.derech-haim.co.il': 0,
#  'i1.services.social.microsoft.com': 0,
#  'p4-h6qjefapfn572-6ubj4c5zsv55iqdi-420867-i2-v6exp3-ds.metric.gstatic.com': 0,
#  'vordu.co.il': 0,
#  'my.mail.ru': 0,
#  'r3---sn-cg07luer.googlevideo.com': 4,
#  'www.nytimes.com': 4,
#  'adblockplus.org': 0,
#  't4ft.de': 0,
#  'sharethis.com': 0,
#  'media.wakavision.com': 0,
#  'az361816.vo.msecnd.net': 8,
#  'api.facebook.com': 23487,
#  'd12i351y3swd4r.cloudfront.net': 0,
#  'www.pashbar.co.il': 0,
#  'www.hwbot.org': 2,
#  'ner.izkor.mod.gov.il': 10,
#  'atmamos.alicdn.com': 0,
#  'img100-106.xvideos.com': 0,
#  'shopvac.cyngn.com': 1726,
#  'www.statesymbolsusa.org': 0,
#  'www.chelationtherapyonline.com': 0,
#  'video-ams2-1.xx.fbcdn.net': 0,
#  'veg.anonymous.org.il': 0,
#  'r10---sn-q0c7dn7l.googlevideo.com': 0,
#  'action1.adit-media.com': 2,
#  'media.data-slimspots.com': 0,
#  'sync.mathtag.com': 62,
#  'impact.applifier.com': 0,
#  'mmv615.whatsapp.net': 8,
#  'www.idi.org.il': 2,
#  '3967926.fls.doubleclick.net': 4,
#  'r6---sn-cg07luer.googlevideo.com': 0,
#  'news2.scepia-sites.co.il': 6,
#  'kbd.data.kpns.ijinshan.com': 4,
#  'ae.ktuvit.com': 2,
#  'r15---sn-5hneznel.googlevideo.com': 0,
#  'www.sdarot.biz': 2,
#  'widget.nanorep.com': 8,
#  'a.rtb.grvcdn.com': 6,
#  'creative.ad120m.com': 2,
#  'upload-community.kipa.co.il': 0,
#  'www.knowledge4all.co.il': 4,
#  'static-avc.lglime.com': 1052,
#  'sony-entrance-sp-proxy.appspot.com': 0,
#  '42.217.209.125.in-addr.arpa': 0,
#  'duapps.com': 0,
#  'track.mct.moblin.com': 28,
#  'static.adikastyle.com': 0,
#  'ws-ext.nana10.co.il': 8,
#  'static-m.u6346p5933.ilykefunny.com': 0,
#  'www.alp.co.il': 0,
#  'p4-fku7x76rc5cws-zjneyxhmfl77rye4-977070-s1-v6exp3-v4.metric.gstatic.com': 0,
#  'www.cff.org': 2,
#  'api.worldnow.com': 2,
#  'r2---sn-nwj7km7r.gvt1.com': 0,
#  'mmi607.whatsapp.net': 20,
#  'www.patreon.com': 2,
#  'p4-fpy63paas2olo-emoglqzp4py4ep4j-809119-s1-v6exp3-v4.metric.gstatic.com': 2,
#  'ok.ru': 1,
#  'us.account.samsung.com': 0,
#  'p4-cavvpbc2kbwas-qgywqmbo3fbsdofz-140622-s1-v6exp3-v4.metric.gstatic.com': 0,
#  'www.linkedin.com': 3089,
#  '94.195.125.74.in-addr.arpa': 28,
#  'rep.erate.co.il': 72,
#  'st0.vk.me': 4,
#  'www.entradas.com': 0,
#  '137.60.193.54.in-addr.arpa': 126,
#  'links.a.co.il': 0,
#  'usabursa.co.il': 0,
#  'b1.zemanta.com': 6,
#  'www.sugat.com': 0,
#  'www.systematics.co.il': 2,
#  'www.ctt.pt': 0,
#  'info.yl-invest.co.il': 0,
#  'bss.allshareplay.com': 4,
#  'm.nydailynews.com': 2,
#  'p4-fhosiecdmffny-rdu6tyaiwiwzjo7z-563621-s1-v6exp3-v4.metric.gstatic.com': 0,
#  'www.soe.ucsc.edu': 0,
#  'gameconnexions.com': 140,
#  'stat.enter-system.com': 12,
#  'fast.mtvn.demdex.net': 0,
#  'tvbythenumbers.zap2it.com': 2,
#  'emea-istrien.netmng.com': 0,
#  'cs.meltdsp.com': 2,
#  'qos-prod-bio-iad-common-common.gos.ea.com': 14,
#  'www.amazon.co.uk': 0,
#  'm.behatsdaa.org.il': 4,
#  'lifestyle.nana10.co.il': 0,
#  'b.scorecardresearch.com': 778,
#  'www.silestone.co.il': 2,
#  'www.doctors.co.il': 0,
#  'ts1.mm.bing.net': 0,
#  'player.ooyala.com': 2,
#  'mp.weixin.qq.com': 30,
#  'com.imangi.s3-website-us-east-1.amazonaws.com': 8,
#  'www.aradon.co.il': 0,
#  'www.fxp.co.il': 16,
#  'www.tamlil2100.co.il': 0,
#  '139.120.202.10.in-addr.arpa': 0,
#  'api.amplitude.com': 165,
#  'r5---sn-q0c7dn7d.gvt1.com': 4,
#  'i.w55c.net': 30,
#  'www.stoliart.co.il': 0,
#  'widgets.ign.com': 4,
#  'gs1.wac.edgecastcdn.net': 2,
#  'www.mwredman.com': 0,
#  'p4-dghageiot3y4m-5jgjgszwv6cyg5na-482792-s1-v6exp3-v4.metric.gstatic.com': 0,
#  'www.newscientist.com': 0,
#  'gallery.mailchimp.com': 6,
#  '9gag.tv': 2,
#  'shealth-image.samsunghealth.com': 4,
#  'goupdate.3g.cn': 8,
#  'www.pinat-hay.com': 0,
#  'r8---sn-q0c7dn76.googlevideo.com': 4,
#  'p4-d2gapax4kkk5s-k73xplt7idp7elqx-104775-i1-unicast.metric.gstatic.com': 0,
#  'besttv29.cdn.it.best-tv.com': 8,
#  'demonstrations.wolfram.com': 0,
#  'adtrack.king.com': 0,
#  'images.ak.instagram.com': 319,
#  'mmv243.whatsapp.net': 2,
#  'a2.opinionstage-res.cloudinary.com': 0,
#  'mikzoan.sherut100.net': 2,
#  'p4-cdkl3oz2sxn7o-u3lfkjgtcdlnczhs-if-v6exp3-v4.metric.gstatic.com': 2,
#  'hadusky.co.il': 0,
#  'allmyvideos.net': 2,
#  'petnet.co.il': 2,
#  'kampai.inforu.mobi': 0,
#  'www.evolo.us': 2,
#  'www.mgo.visionbox.co.il': 0,
#  'r19---sn-vgqs7n7s.googlevideo.com': 0,
#  'www.mophie.com': 0,
#  'cdn.optimizely.com': 1222,
#  'r19---sn-aigllnlr.googlevideo.com': 0,
#  'thumbnails-02.gp-static.com': 4,
#  'img100-789.xvideos.com': 0,
#  'hn.inspectlet.com': 6,
#  'www.dogslife.org.il': 0,
#  'impie.tradedoubler.com': 2,
#  'www.wallatours.co.il': 36,
#  'cyber.calcalist.co.il': 2,
#  'secure-uk.imrworldwide.com': 2,
#  'youzanporn.com': 0,
#  '2.158.220.66.in-addr.arpa': 62,
#  '8ca6a693.api.splkmobile.com': 58,
#  'dailyliked.net': 0,
#  'm.wsj.net': 0,
#  'api.skype.com': 56,
#  'www.insertlifehere.net': 0,
#  'images.applicaster.com': 12,
#  'www.cs.sunysb.edu': 0,
#  'r10---sn-q0c7dn7e.googlevideo.com': 4,
#  'at.alenty.com': 0,
#  'yandex.st': 0,
#  'r11---sn-q0c7dn7l.gvt1.com': 10,
#  'www.eza.co.il': 2,
#  'r14---sn-q0c7dn76.googlevideo.com': 4,
#  'ad.sxp.smartclip.net': 16,
#  'cd.lenzmx.com': 2,
#  'mmv214.whatsapp.net': 0,
#  't.mookie1.com': 10,
#  'mmi645.whatsapp.net': 14,
#  'cdn.feeds.videosz.com': 6,
#  'trophy01.np.community.playstation.net': 0,
#  'tracker.veryamt.com': 0,
#  'www.redbulletin.com': 2,
#  'www.betfair.com': 2,
#  'r8---sn-o097zuez.googlevideo.com': 0,
#  'ad.directrev.com': 6,
#  'www.cardcom.co.il': 0,
#  'www.mooviees.com': 2,
#  'track.hubspot.com': 2,
#  'affiliate.integral-marketing.com': 0,
#  'www.campaigns.hotnet.net.il': 2,
#  'ei.rlcdn.com': 0,
#  'gs.mindjolt.com': 28,
#  '216.112.194.173.in-addr.arpa': 2,
#  'overhaps.com': 2,
#  'compare-consumer-reviews.com': 2,
#  '0.US.pool.ntp.org': 0,
#  'nahaldarga.org.il': 2,
#  'p4-fpy63paas2olo-emoglqzp4py4ep4j-if-v6exp3-v4.metric.gstatic.com': 2,
#  'h.live.com': 0,
#  'hiname.co': 2,
#  'c.go-mpulse.net': 0,
#  'www.valigar.com': 0,
#  'd.adroll.com': 16,
#  'www.leg.state.mn.us': 0,
#  'cs.microsoft.com': 0,
#  'videos-d-2.ak.instagram.com': 2,
#  'recon-ecc.aws-protocol-testing.com': 0,
#  'm.frogi.co.il': 70,
#  'motileybel.files.wordpress.com': 4,
#  '90.118.89.54.in-addr.arpa': 2,
#  'r3---sn-q4f7dm7k.gvt1.com': 0,
#  'spo55ru.blogspot.com': 2,
#  'et.w.inmobi.com': 0,
#  'r5---sn-vgqsem76.gvt1.com': 0,
#  'uk.finance.yahoo.com': 0,
#  'css.opposingviews.com': 0,
#  'imap.gmail.com': 356,
#  'woodstockfestival.pl': 0,
#  'mackeeperapp.mackeeper.com': 0,
#  'p4-hud2wn4q2xubm-2cuzaz5gfj2wxtjf-281080-i1-v6exp3-ds.metric.gstatic.com': 0,
#  'mrtb-nj.lfstmedia.com': 0,
#  'casale-cm.p.veruta.com': 6,
#  'cdn.flipboard.com': 4,
#  'r14---sn-q0c7dn7y.gvt1.com': 4,
#  'www.bubulu.net': 3,
#  'www.ticketingcentral.com': 0,
#  'sync2.adsniper.ru': 4,
#  'files5.adme.ru': 0,
#  'www.trackimpression.com': 4,
#  'www.egged-taavura.co.il': 0,
#  'aristo4bgu.bgu.ac.il': 0,
#  'p4-e3w73tejvow5o-hxfky6yuobi46qfl-408144-s1-v6exp3-v4.metric.gstatic.com': 0,
#  'www.marvel.com': 0,
#  'davidson.weizmann.ac.il': 2,
#  'www.studioc.co.il': 0,
#  'www.19actionnews.com': 2,
#  'hamadrich.idc.ac.il': 0,
#  'nmsites.nextopic.com': 0,
#  'r2---sn-4g57kuel.googlevideo.com': 0,
#  'www.zoomd.com': 0,
#  'i61.tinypic.com': 0,
#  'go.microsoft.com': 0,
#  'r8---sn-q4f7dm7k.googlevideo.com': 0,
#  'newsstand.googleusercontent.com': 51,
#  'freecrochetpattern.weebly.com': 2,
#  'videos-h-15.ak.instagram.com': 12,
#  'r14---sn-a5mekm7k.gvt1.com': 0,
#  'p4-cji4je5dhkqzg-7lble6oiw3q47xaa-if-v6exp3-v4.metric.gstatic.com': 0,
#  'ttsgw.world.waze.com': 164,
#  'www.blastr.com': 2,
#  'mmv285.whatsapp.net': 4,
#  'appnext-a.akamaihd.net': 10,
#  'r6---sn-ab5e6m7e.googlevideo.com': 0,
#  'r11---sn-4g57kndk.googlevideo.com': 0,
#  'securedrop.theguardian.com': 0,
#  'incoming.cloud-trax.com': 0,
#  'heavy.com': 4,
#  'www.bgu.co.il': 2,
#  'resources.kiosked.com': 0,
#  'wallofcoins.com': 16,
#  '03c17a9.netsolhost.com': 2,
#  'www.novisign.co.il': 0,
#  'checkout.google.com': 2,
#  'secure.pow7.com': 0,
#  'live.sekindo.com': 420,
#  'www.cbsinteractive.com': 0,
#  'www.yourtango.com': 4,
#  'www.yes.co.il': 2,
#  'sp.fastclick.net': 2,
#  'p4-fny2hunvvy7ou-lsgv5t5akhdx5loy-989180-i2-v6exp3-v4.metric.gstatic.com': 2,
#  'www.winwin.co.il': 2,
#  'www.behatsdaa-nadlan.com': 4,
#  'visit.maccabi4u.co.il': 4,
#  'd1fnuwuy1vks2k.cloudfront.net': 6,
#  'forms.verizonwireless.com': 0,
#  'mmv279.whatsapp.net': 4,
#  'www.mouse.co.il': 10,
#  'community.videogamer.com': 2,
#  'af-gb.mgid.com': 0,
#  'm.jerusalem.azrieli.com': 2,
#  'www.seat.co.il': 2,
#  'www.megalim.co.il': 0,
#  'www.xn--4dbdhcduba8b8cxbf.net': 2,
#  '487-events.olark.com': 2,
#  'api.instagram.com': 8,
#  'r13---sn-a5m7znez.googlevideo.com': 0,
#  'encarta.msn.com': 2,
#  'attachment.fbsbx.com': 10,
#  'geo.widdit.com': 0,
#  'videos-c-10.ak.instagram.com': 14,
#  'analytics.revee.com': 0,
#  'direct.tranzila.com': 0,
#  'ads.ad4game.com': 4,
#  'cms.quantserve.com': 8,
#  'r3---sn-q0c7dn7s.googlevideo.com': 0,
#  'files3.adme.ru': 0,
#  'cdn1.media.trafficjunky.net': 2,
#  'he.urbandictionary.com': 0,
#  'm.quantcount.com': 0,
#  'tr.urbandictionary.com': 0,
#  'videos-d-11.ak.instagram.com': 14,
#  'content.dictionary.com': 0,
#  'www.todaysiphone.com': 0,
#  'static.arcgis.com': 0,
#  'upoll.umengcloud.com': 1293,
#  'poalot.com': 0,
#  'w3server.t17service.com': 0,
#  'r1---sn-cg07luel.googlevideo.com': 0,
#  'pop.bleacherreport.com': 2,
#  'ss7.vzw.com': 0,
#  'locksmithcourse.ravpage.co.il': 0,
#  '36.media.tumblr.com': 0,
#  'p4-auwgyrf2h2qec-fhe4v2th46fs5cbd-198638-i1-v6exp3-ds.metric.gstatic.com': 2,
#  'easy.co.il': 10,
#  'www.third-ear.com': 0,
#  'www.trbimg.com': 0,
#  'android.clients.google.com.bgu.ac.il': 13,
#  'www.tri-max.co.il': 2,
#  'qos-prod-bio-sjc-common-common.gos.ea.com': 14,
#  'auth.np.ac.playstation.net': 0,
#  'www.raycommedia.com': 2,
#  'mmv288.whatsapp.net': 0,
#  'www.tellows.com': 0,
#  'instagramimages-a.akamaihd.net': 138,
#  'www.maccabi-tlv-shop.co.il': 0,
#  'mmv215.whatsapp.net': 0,
#  'ais-api.applicaster.com': 8,
#  'iheartdogs.com': 0,
#  'ko.wikipedia.org': 0,
#  'p4-etywnujvmvkju-c2glnkeobnux3ral-457142-s1-v6exp3-v4.metric.gstatic.com': 0,
#  'aloha.viber.com': 862,
#  'theforma.myshopify.com': 0,
#  'img100-405.xvideos.com': 0,
#  'es.uefa.com': 2,
#  'www.wellingtonsecurity.net': 0,
#  'videos-d-14.ak.instagram.com': 4,
#  'boots.scene7.com': 0,
#  'www.thc.org.il': 0,
#  'www.sexmovie.co.il': 0,
#  'ipango.itip.co.il': 28,
#  'shironet.mako.co.il': 0,
#  'shop.eurovision.tv': 0,
#  '115.2.250.178.in-addr.arpa': 0,
#  'bmaeu.badoo.com': 104,
#  'dictionary.reference.com': 0,
#  'www.hefty.co': 0,
#  'router.infolinks.com': 0,
#  'r20---sn-q0c7dn7s.googlevideo.com': 0,
#  'www.valigar.co.il': 0,
#  'scripts.kissmetrics.com': 0,
#  'srv.exposebox.com': 12,
#  'join-talent.com': 0,
#  'openjobs.co.il': 0,
#  'www.onlineadsnetwork.com': 2,
#  'r16---sn-q0c7dn7l.gvt1.com': 0,
#  'poll.walla.co.il': 2,
#  'html5shiv.googlecode.com': 2,
#  'r5---sn-cg07luek.googlevideo.com': 0,
#  'p.jango.com': 0,
#  'banners1.bizportal.co.il': 2,
#  'img.mediaplex.com': 0,
#  'd4757.allmyvideos.net': 2,
#  'yeda.bgu.co.il': 2,
#  'api.facebook.com.ac.il': 4,
#  'cdn.kixer.com': 14,
#  'gwc.lphbs.com': 6,
#  'www.fcbarcelona.com': 4,
#  'therealstanlee.com': 0,
#  'dt.scanscout.com': 22,
#  'seethisinaction.com': 6,
#  'videos-a-5.ak.instagram.com': 8,
#  'www.htc.com': 118,
#  'www.jewishjournal.com': 0,
#  'fbcdn-vthumb-a.akamaihd.net.bgu.ac.il': 0,
#  'local.chron.com': 2,
#  'www.preventionweb.net': 0,
#  'cluster18b.heavy-r.com': 2,
#  'uc.cm.ksmobile.com': 4,
#  'login.dotomi.com': 0,
#  'p4-gkbmv6ehvsgha-qkmpeqhw2yvg5yf3-532964-s1-v6exp3-v4.metric.gstatic.com': 0,
#  'www.reidman.co.il': 0,
#  's.aolcdn.com': 2,
#  'fashionforward.mako.co.il': 20,
#  'c.t4ft.de': 0,
#  'dx0qysuen8cbs.cloudfront.net': 0,
#  'mxnet.ynet.co.il': 6,
#  'distilleryvesper3-15.ak.instagram.com': 4,
#  'adserver.adtechus.com': 8,
#  'device.4seeresults.com': 6,
#  'ht.cdn.turner.com': 0,
#  'ar.thomsonreuters.com': 0,
#  'www.dakotayeast.com': 0,
#  'www.listandtell.co.il': 8,
#  'atp.mxptint.net': 2,
#  'by.uservoice.com': 1170,
#  's3.amazonaws.com.bgu.ac.il': 9,
#  'blogs.sonymobile.com': 0,
#  'www.streamnowmovies.com': 0,
#  'img3.yiwutalk.com': 2,
#  's.ad135m.com': 0,
#  'www.rivitmedia.com': 0,
#  'da.wikipedia.org': 2,
#  'www.red-fans.com': 2,
#  'plus.google.com': 152,
#  'www.eonline.com': 0,
#  'data.bnf.fr': 0,
#  'mediadownload.calcalist.co.il': 2,
#  'android.googleapis.com': 6510,
#  'www.comicbookresources.com': 0,
#  'p4-boeztdr7ljnio-jd7tfqijiecosz3a-602670-i2-v6exp3-v4.metric.gstatic.com': 0,
#  'happykitchenil.files.wordpress.com': 0,
#  'www.qq.com': 40,
#  'www.wobi.co.il': 32,
#  'r6---sn-hp57knlr.googlevideo.com': 0,
#  'mobile.askpeople.co.il': 0,
#  'r3---sn-p5qlsnsk.googlevideo.com': 0,
#  'math1.cet.ac.il': 0,
#  'samsungbuiasr.vlingo.com': 87,
#  'mazaltov.walla.co.il': 14,
#  'img5.timeinc.net': 0,
#  'ads.creative-serving.com': 2,
#  'www.eurovision.tv': 0,
#  'wims.unice.fr': 0,
#  'www.translatesonline.com': 0,
#  'www.pc.co.il': 0,
#  'www.hear.org': 0,
#  'sslstatic.wix.com': 2,
#  'r18---sn-ab5e6m7l.googlevideo.com': 0,
#  'secure.opinionlab.com': 0,
#  'adclick.g.doubleclick.net': 68,
#  'ready.org.il': 0,
#  'p4-dgpambceyjtlu-rzp6motgb4v5h5vz-348958-i2-v6exp3-v4.metric.gstatic.com': 0,
#  'api.sherut.net': 2,
#  'cdn.thumbs.roadshamer.com': 2,
#  'www.iphonezone.co.il': 0,
#  'www.math.nmsu.edu': 0,
#  'downloads.mailchimp.com': 2,
#  'comlead.net': 0,
#  'cosu.sonymobile.com': 12,
#  'sock55.pusher.com': 0,
#  '62296.0.2.5.20703.rst1.r.skype.net': 0,
#  'www.yl-invest.co.il': 2,
#  'img100-312.xvideos.com': 0,
#  'www.filmon.com': 2,
#  'il-prof.np.community.playstation.net': 2,
#  'portal.k12.il': 2,
#  'bn1files.storage.msn.com': 4,
#  'cas.pxl.ace.advertising.com': 12,
#  'www.blogtopsites.com': 0,
#  'israel.thebeehive.org': 2,
#  'www.showoff.co.il': 2,
#  'www.amazon.de': 0,
#  'r9---sn-vgqsem7z.googlevideo.com': 0,
#  'r8---sn-q0c7dn7z.gvt1.com': 2,
#  'ja.wikipedia.org': 0,
#  'www.goldtip.co.il': 0,
#  'viva.walla.co.il': 12,
#  'www.calcalist.co.il': 88,
#  'r1---sn-h5jic5-ua8e.gvt1.com': 0,
#  'dquery.neto.co.il': 0,
#  'b.thumbs.redditmedia.com': 2,
#  'cdn.ctnsnet.com': 4,
#  'gld.push.samsungosp.com': 10,
#  'gl.wikipedia.org': 0,
#  'healthy.walla.co.il': 86,
#  'iriya.bgu4u.co.il': 0,
#  'ads2.contentabc.com': 8,
#  'static.viralnova.com': 2,
#  '195.194.18.50.in-addr.arpa': 38,
#  'api-ak3.wunderground.com': 36,
#  'search.midomi.com': 0,
#  'www.thisis50.com': 2,
#  'news.walla.co.il': 126,
#  'p4-af5yseze3kn2s-7a65jhee6vwhai6c-789789-s1-v6exp3-v4.metric.gstatic.com': 2,
#  'sb.freeskreen.com': 16,
#  'bruce.orel.ws': 0,
#  'p4-enc7wfybxaasa-zkg6dyfbzaousdg3-447489-s1-v6exp3-v4.metric.gstatic.com': 0,
#  'project.saatchi-interactive.co.il': 0,
#  'chart.apis.google.com': 6,
#  'tickets.b7t.co.il': 2,
#  'conversions.adaptv.advertising.com': 4,
#  'r4---sn-p5qlsnsy.googlevideo.com': 0,
#  'sftimes.s3.amazonaws.com': 0,
#  'kraken-measurements.s3.amazonaws.com': 12,
#  'farm4.static.flickr.com': 2,
#  'mortalkombat.wikia.com': 4,
#  'portal.manjushri.alibaba.com': 0,
#  'eventsalt30.adcolony.com': 4,
#  'makinggamesisfun.co.uk': 0,
#  'umano.me': 0,
#  'www.dailytelegraph.com.au': 2,
#  'www.qualtrics.com': 4,
#  'vap2dfw1.lijit.com': 2,
#  '2-edge-chat.facebook.com': 0,
#  'www.predictad.com': 0,
#  'p4-fyoduiwf5euba-waxbnkjxwb723vqr-if-v6exp3-v4.metric.gstatic.com': 0,
#  'www.sniper-m.com': 0,
#  'distilleryimage6.ak.instagram.com': 56,
#  '0.client-channel.google.com': 0,
#  'www.bus.co.il': 4,
#  'www.skyscanner.no': 0,
#  'csdl.engin.umich.edu': 0,
#  'de16.zopim.com': 0,
#  'flix.tapuz.co.il': 4,
#  'server.cappsool.com': 30,
#  'lb-wdc.mdotm.co': 0,
#  'thumbnails-04.gp-static.com': 12,
#  'sonymobile-sc-fb-like-config.s3.amazonaws.com': 0,
#  'ps15.pubnub.com': 0,
#  'p4-capr2jiu5cw6c-cxd553pz2zdkywcv-if-v6exp3-v4.metric.gstatic.com': 0,
#  'videos-f-8.ak.instagram.com': 2,
#  'm.hotmail.com': 40,
#  'twitpic.com': 2,
#  'adservices.picadmedia.com': 0,
#  'join.yes.co.il': 2,
#  'profile.localytics.com': 0,
#  'www3.interscience.wiley.com': 2,
#  'c1.navrcholu.cz': 0,
#  'srx.main.ebayrtm.com': 0,
#  'www.forom.ws': 4,
#  'by3301files.storage.live.com': 4,
#  'mmv223.whatsapp.net': 8,
#  'ads.adsonar.com': 0,
#  'mavir.co.il': 0,
#  'news-front.info': 2,
#  'r3---sn-cg07lue6.googlevideo.com': 0,
#  'aa-gb.mgid.com': 0,
#  'videos-a-11.ak.instagram.com': 8,
#  'fellows.acm.org': 0,
#  'api.vungle.com': 22,
#  'staff.jccc.net': 0,
#  'histclo.com': 2,
#  'ggimg.tapas.net': 18,
#  'cdn.iheartsecret.com': 8,
#  'gateway.ea.com': 44,
#  'api.dmcdn.net': 2,
#  'r16---sn-ab5l6nee.googlevideo.com': 0,
#  'passionfruitads.s3.amazonaws.com': 0,
#  'static.rottentomatoes.com': 2,
#  'd2ymkpxi1rgldj.cloudfront.net': 102,
#  'heydrichr.blogspot.co.il': 0,
#  'www.chinabuy.co.il': 0,
#  'rover.ebay.com': 16,
#  'mmv303.whatsapp.net': 4,
#  'pr-bh.ybp.yahoo.com': 0,
#  'forms.gov.il': 0,
#  'mmi627.whatsapp.net': 10,
#  'www.parter.ru': 0,
#  'segments.wt-data.com': 12,
#  'explore.bfi.org.uk': 2,
#  'benshahar.wix.com': 2,
#  'www.hapoelb7.co.il': 0,
#  'adxhm.d.chango.com': 18,
#  'contentz.mkt2732.com': 0,
#  'www.shufersalblog.co.il': 0,
#  'tolkiengateway.net': 2,
#  'topoffer.mobi': 0,
#  'cdn1.clkrev.com': 2,
#  'ads.trafficjunky.net': 6,
#  'ad6e42d0971d1df653b52d4b02bbc7469.profile.mnl50.cloudfront.net': 0,
#  'www.dailymail.co.uk': 12,
#  'cdn.petametrics.com': 2,
#  'www.supersize.co.il': 2,
#  'distilleryvesper6-2.ak.instagram.com': 0,
#  'blog.012.net': 0,
#  'www.ynet.co.ilwww.calcalist.co.il': 0,
#  'archive.southwalesguardian.co.uk': 2,
#  'bks2.books.google.com': 8,
#  'www1066.mdotm.com': 0,
#  'manager.spotgam.es': 16,
#  'csbi.htcsense.com': 4,
#  'www.nifgashim.net': 0,
#  'p4-d5wsxdls3bqus-u5wpitzst4qjbnv5-759726-i1-v6exp3-ds.metric.gstatic.com': 0,
#  'r10---sn-q0c7dn7z.googlevideo.com': 4,
#  'sl.doctorim.co.il': 0,
#  'calcalist.the-insider.co.il': 4,
#  'logc405.xiti.com': 2,
#  'www.mayachen.co.il': 0,
#  'cdn2.digitaltrends.com': 0,
#  'diply.com': 0,
#  'ayalim.org.il': 0,
#  'kona5.kontera.com': 0,
#  'www.tatranmusic.com': 0,
#  'pixel.moatads.com': 4,
#  'edge.quantserve.com': 50,
#  '31.217.209.125.in-addr.arpa': 4,
#  'p4-e5gm3ufjqxnwa-kolfymmsvau2bbp2-209229-i1-v6exp3-v4.metric.gstatic.com': 0,
#  'prognathous.mail-central.com': 0,
#  'sso.zap.co.il': 6,
#  'api.houzz.com': 24,
#  'www.sportfluff.com': 2,
#  'static.entrance.sonymobile.com': 0,
#  'serve.omni-ads.com': 0,
#  'www.bgu.ac.il': 4,
#  '186.81.59.108.in-addr.arpa': 0,
#  'static.amazon.com': 0,
#  'video.google.com': 2,
#  'p4-c7czwc75ozhya-vafwzdq5mlznr7hh-if-v6exp3-v4.metric.gstatic.com': 2,
#  'r10---sn-nwj7knes.googlevideo.com': 0,
#  'stage-a.applovin.com': 0,
#  'videos-d-4.ak.instagram.com': 2,
#  'us46.zopim.com': 0,
#  'www.adidas.co.il': 0,
#  'go.mobilix.eu': 0,
#  'mediaserver.bgu.ac.il': 2,
#  'trk.bidtrk.com': 2,
#  'twitter.com': 478,
#  'www.goshow.co.il': 2,
#  'us20.zopim.com': 0,
#  'a650.casalemedia.com': 0,
#  'p4-afspqwasiukii-ida2e6uwlos6iyd2-if-v6exp3-v4.metric.gstatic.com': 0,
#  'rhtag.com': 4,
#  'img100-877.xvideos.com': 0,
#  'ad1.adit-media.com': 4,
#  'p4-budcds3hce3fk-223tm4ypvteukl5q-882144-s1-v6exp3-v4.metric.gstatic.com': 0,
#  'tapstream.tapatalk.com': 0,
#  'p.d41.co': 4,
#  'img6a.flixcart.com': 0,
#  'g.alicdn.com': 2,
#  'beacons.gvt2.com': 31,
#  'r1---sn-q0c7dn7y.googlevideo.com': 6,
#  'api.linkedin.com': 154,
#  'mmi216.whatsapp.net': 38,
#  'wa.vodafone.ie': 0,
#  'r6---sn-cg07luee.googlevideo.com': 0,
#  'sjc-uhls-proxy06.ustream.tv': 4,
#  'content.pollonize.com': 2,
#  'spring14.gosredirector.ea.com': 14,
#  'e1.static.hoptopboy.com': 6,
#  'mmi110.whatsapp.net': 10,
#  'usa.autodesk.com': 0,
#  'r6---sn-hp57kn7e.googlevideo.com': 0,
#  'serve.qriously.com': 2,
#  'g1.globo.com': 0,
#  'click4.truecaller.com': 14,
#  'a338.casalemedia.com': 2,
#  'mmi226.whatsapp.net': 38,
#  'r7---sn-q0c7dn7s.googlevideo.com': 8,
#  'nist1-lnk.binary.net': 0,
#  'mobile.bankleumi.co.il': 34,
#  'www.claymath.org': 0,
#  'orionimg.adkmob.com': 4,
#  'p4-hosak5vmgy456-z3txqjpx7wxempke-845190-s1-v6exp3-v4.metric.gstatic.com': 0,
#  'cdn.theguardian.tv': 10,
#  'goviralengine.cloudapp.net': 0,
#  'p4-ak2ihynhvlebw-amnb7ktaoxl55nck-960819-i2-v6exp3-ds.metric.gstatic.com': 2,
#  'libs.de.coremetrics.com': 2,
#  'gi-israel.info': 0,
#  'videos-c-19.ak.instagram.com': 0,
#  'www.ishim.co.il': 2,
#  'videos-e-13.ak.instagram.com': 4,
#  'geektyrant.com': 0,
#  'speedtestgz.hadara.ps': 4,
#  'clients3.google.com': 19328,
#  'img100-949.xvideos.com': 0,
#  '20.346ab3474261484093a145656974f92c.app.ktcfg.net': 0,
#  'pubservcdn.picadmedia.com': 0,
#  'static-resource.np.community.playstation.net': 2,
#  'gentlebarn.org': 0,
#  'clients4.google.com': 10691,
#  'sex4free.co.il': 4,
#  '2.pool.ntp.org': 7,
#  'security.bgu.ac.il': 0,
#  'www.hellotravel.com': 2,
#  'i.ctnsnet.com': 32,
#  'adb.adledge.com': 6,
#  'ar.wikipedia.org': 2,
#  'r1---sn-cg07lued.googlevideo.com': 0,
#  'lt.wikipedia.org': 0,
#  'r4---sn-cg07luel.googlevideo.com': 4,
#  'ip.casalemedia.com': 12,
#  'scontent.cdninstagram.com': 454,
#  'network.adsmarket.com': 2,
#  'r4---sn-cg07luee.googlevideo.com': 10,
#  'bdv.bidvertiser.com': 6,
#  'cdn1a.static.pornhub.phncdn.com': 6,
#  'p4-cx356fjqz3kom-lv5agz4jgn5gsin2-963023-i1-v6exp3-v4.metric.gstatic.com': 0,
#  'ec01.cooladata.com': 125,
#  'gaby1.hit.gemius.pl': 0,
#  'nl.youporn.com': 0,
#  'www.homie.co.il': 0,
#  'mytm.nrg.co.il': 0,
#  'mmv249.whatsapp.net': 4,
#  'i1-j4-18-6-1-13960-3719423837-s.init.cedexis-radar.net': 0,
#  'www.ims.gov.il': 0,
#  'my.ynet.co.il': 6,
#  'www.canneszions.com': 0,
#  'r19---sn-q0c7dn7s.gvt1.com': 4,
#  'www.messi2day.com': 2,
#  'textologia.net': 0,
#  'providence.voxmedia.com': 0,
#  'xtrapath2.izatcloud.net': 51,
#  'www.citypay.co.il': 0,
#  'd29oav93j91bc6.cloudfront.net': 4,
#  'suwidget3.sphereup.com': 0,
#  'videos-h-6.ak.instagram.com': 4,
#  'seattleclouds.com': 0,
#  'demilked.disqus.com': 2,
#  'flr5.cbox.ws': 2,
#  ...}

# %%
domains_usage_count_df = pd.DataFrame.from_dict(
    {'domains': list(domains_usage_count.keys()), 'usage': list(domains_usage_count.values())})
domains_usage_count_df = domains_usage_count_df.sort_values('usage', ascending=False)

# Avg of unique domains per user from valid domains:
print("Number of valid domains {}. Examples:".format(len(valid_domains)))
print(domains_usage_count_df.head())
# Out:
# Number of valid domains 11808. Examples:
#                           domains  usage
# 10816          graph.facebook.com  40112
# 5905               www.google.com  31716
# 5951              app.woorlds.com  29473
# 6486   android.clients.google.com  26122
# 9812     settings.crashlytics.com  25002

# %%
print("\n====Statistics with only valid domains:====\n")
# Average of domains without duplication per user : 4236.
domains_without_duplication_per_user = []
for user in users_data:
    domains_without_duplication_per_user.append(len((set(user['dns.qry.name']) - suspicious_domains)))

print("Average of domains without duplication per user : {}"
      .format(reduce(lambda x, y: x + y, domains_without_duplication_per_user) / len(users_data)))
print("Min of domains without duplication per user : {}".format(min(domains_without_duplication_per_user)))
print("Max of domains without duplication per user : {}".format(max(domains_without_duplication_per_user)))
# Out:
# ====Statistics with only valid domains:====
#
# Average of domains without duplication per user : 1887.4666666666667
# Min of domains without duplication per user : 758
# Max of domains without duplication per user : 2981

# %%
# Domain used only by specific user
unique_domains_per_user_valid = []
for index, user in enumerate(domains_per_user):
    user_domains = copy.deepcopy(user)
    user_domains -= suspicious_domains
    for u in domains_per_user[:index]:
        user_domains -= u

    for u in domains_per_user[index + 1:]:
        user_domains -= u

    unique_domains_per_user_valid.append(len(user_domains))
    # print("Unique domain for user {} is {}".format(index, len(user_domains)))

print("Average of domains only used by specific users : {}"
      .format(reduce(lambda x, y: x + y, unique_domains_per_user_valid) / len(users_data)))
print("Min of domains only used by specific user : {}".format(min(unique_domains_per_user_valid)))
print("Max of domains only used by specific user : {}".format(max(unique_domains_per_user_valid)))
# Out:
# Average of domains only used by specific users : 530.1333333333333
# Min of domains only used by specific user : 74
# Max of domains only used by specific user : 1224

# %%
# Valid domains which all users use:
valid_domains_used_by_all_users = set()
for domain in valid_domains:
    everyone_use_this_domain = True
    for user in domains_per_user:
        if domain not in user:
            everyone_use_this_domain = False
            break
    if everyone_use_this_domain:
        valid_domains_used_by_all_users.add(domain)

# %%
# Remove domain used by all users from domains_usage_count_df
everyone_domains_usage_count_df = pd.DataFrame(columns=['domains', 'usage'])
for domain in valid_domains_used_by_all_users:
    everyone_domains_usage_count_df = pd.concat(
        [everyone_domains_usage_count_df, domains_usage_count_df.loc[domains_usage_count_df['domains'] == domain]])
    domains_usage_count_df.drop(domains_usage_count_df.loc[domains_usage_count_df['domains'] == domain].index,
                                inplace=True)

everyone_domains_usage_count_df = everyone_domains_usage_count_df.sort_values('usage', ascending=False)

# %%
domains_usage_count_df
# Out:
#                                                  domains  usage
# 5951                                     app.woorlds.com  29473
# 329                                     api.facebook.com  23487
# 1043                              edge-mqtt.facebook.com  15444
# 11415                                 up.cm.ksmobile.com  12723
# 2481                                    logjam.cyngn.com   9774
# 1845                                      push.parse.com   9586
# 7817                         device-api.urbanairship.com   7657
# 5174                                   api.appsflyer.com   6927
# 6979                              2.android.pool.ntp.org   6708
# 1586                                     api.dropbox.com   6625
# 8820                                b-graph.facebook.com   5499
# 3699                                    inbox.google.com   4560
# 2125                                  cmdts.ksmobile.com   4447
# 10201                        fbcdn-vthumb-a.akamaihd.net   4257
# 11351                                api.crittercism.com   3258
# 11332                                  mqtt.facebook.com   3257
# 3208                         secure-drm.imrworldwide.com   3250
# 2443                                    api.gotinder.com   3249
# 379                                     www.linkedin.com   3089
# 1448                                  dl.sj.ijinshan.com   3059
# 5602                                   api.tapstream.com   2787
# 11391                          superpharm.api.moblin.com   2783
# 8898                                     infoc2.duba.net   2765
# 11230                                  e.crashlytics.com   2686
# 1179                                    s3.amazonaws.com   2561
# 3082                                  adash.m.taobao.com   2495
# 6827                                 decide.mixpanel.com   2410
# 8100                                zj.dcys.ksmobile.com   2312
# 9229                                    api.mixpanel.com   2173
# 2468                                dcys-en.ijinshan.com   2131
# ...                                                  ...    ...
# 5170   p4-adahjevtjdwei-q3b36yyuuw5sqddk-349431-s1-v6...      0
# 5172                    r9---sn-aigllne7.googlevideo.com      0
# 5198                                 whymusicmatters.com      0
# 5214                                      wakavision.net      0
# 5213                                 images.playbill.com      0
# 5211                                        uk.yahoo.com      0
# 5210                              www.praxellpayroll.com      0
# 5208                                     mapateva.org.il      0
# 5207                               files.bannersnack.net      0
# 5206                                   static.sfdict.com      0
# 5205                       widget-prime.rafflecopter.com      0
# 5203                                       www.lijit.com      0
# 5202                                  www.eilat-city.net      0
# 5201                                dub120.mail.live.com      0
# 5200                                       a.kym-cdn.com      0
# 5197                                   www.cellcom.co.il      0
# 5173                                     www.infacta.com      0
# 5196                                      cn.ibtimes.com      0
# 5195                              www.shoam-police.co.il      0
# 5193                                        s.ad126m.com      0
# 5192                                          flxsys.com      0
# 5190                                       receptishi.ru      0
# 5188   p4-g6wzdw3j2a4fw-cjboopbv4a6aplch-630568-i2-v6...      0
# 5187                                     www.liana.co.il      0
# 5186                         videos-e-3.ak.instagram.com      0
# 5183                                tealium.hs.llnwd.net      0
# 5182                                   www.peersmart.org      0
# 5179                                callingjustified.com      0
# 5175                                 ucs.query.yahoo.com      0
# 11807                 thehobbitfilms.files.wordpress.com      0
#
# [11664 rows x 2 columns]

# %%
valid_domains
# Out:
# {'us.my.alibaba.com',
#  'www1063.mdotm.com',
#  'r6---sn-q4f7dm7l.googlevideo.com',
#  'mmi115.whatsapp.net',
#  'chatdepot.twitch.tv',
#  'mekomit.co.il',
#  'psapp-start.dl.playstation.net',
#  '65524.0.3.5.20703.rst15.r.skype.net',
#  'p4-dghageiot3y4m-5jgjgszwv6cyg5na-482792-i1-v6exp3-ds.metric.gstatic.com',
#  'seretil.me',
#  'www.middleeasteye.net',
#  'e13.whatsapp.net',
#  'p4-cqaofin4hk7p6-chkef5svkhbn2kl6-275209-i1-v6exp3-v4.metric.gstatic.com',
#  'cdn-1.convertexperiments.com',
#  'cdn1.clkmon.com',
#  'app.sketch.sc.sonymobile.com',
#  'igy-il.disqus.com',
#  'mmi218.whatsapp.net',
#  'videos-b-16.ak.instagram.com',
#  'r20---sn-q0c7dn7k.gvt1.com',
#  'r4---sn-q0c7dn7k.googlevideo.com',
#  's.ad132m.com',
#  '136.178.215.54.in-addr.arpa',
#  'mmv283.whatsapp.net',
#  'www.underwar.co.il',
#  'mgid.com',
#  'justwhookid.disqus.com',
#  'www.fisheye.co.il',
#  'www.maslulim-israel.co.il',
#  'tapestry.tapad.com',
#  'load.passionfruitads.com',
#  'p4-bnaiwa6hzndlg-txx4r5tsa4ljnx7d-962642-s1-v6exp3-v4.metric.gstatic.com',
#  'p-behacdn.ksmobile.net',
#  'fogeli.co.il',
#  'xwbe.wcdn.co.il',
#  'r1---sn-q0c7dn7s.googlevideo.com',
#  'bank-5.ads.mp.mydas.mobi',
#  'static.apester.com',
#  'wms-na.amazon-adsystem.com',
#  'heritage-key.com',
#  'web.archive.org',
#  'matterdome.com',
#  'videos-c-17.ak.instagram.com',
#  'img100-288.xvideos.com',
#  'rum-collector.pingdom.net',
#  'cdn-media.web-view.net',
#  'cdn.skum.eamobile.com',
#  'd9hhrg4mnvzow.cloudfront.net',
#  'evernote-a.akamaihd.net',
#  '191.112.194.173.in-addr.arpa',
#  '32d1d3b9c.se',
#  'net.nana10.co.il',
#  'i.s-microsoft.com',
#  'www.mobitti.com',
#  'mtalk.google.com.ac.il',
#  'sportsillustrated.cnn.com',
#  'img100-270.xvideos.com',
#  'www.nlm.nih.gov',
#  'creativework.mtv.com.au',
#  'ronangelo.com',
#  'wokinfo.com',
#  'www2.sawlive.tv',
#  'shared.mtv.com',
#  'www.tinylinks.co',
#  'scholar.lmgtfy.com',
#  'cdn.pubexchange.com',
#  'eu.dr.skype.net',
#  'insight.adsrvr.org',
#  'ru.aliexpress.com',
#  'gp6.googleusercontent.com',
#  'mmv669.whatsapp.net',
#  'www.eventim.ro',
#  'porn.im.36483300.2404796.x.xvideos.com',
#  'www.lapidtec.co.il',
#  'audience.powerlinks.com',
#  'istudent.co.il',
#  'mb.mtv.com',
#  'maps.apple.com',
#  'streamfifamatches.tv',
#  'p4-cavvpbc2kbwas-qgywqmbo3fbsdofz-if-v6exp3-v4.metric.gstatic.com',
#  'm.castro.com',
#  'play.google.com',
#  'm.soundcloud.com',
#  'p.raasnet.com',
#  'tracking.keywee.co',
#  'ecnmedia.static-economist.com',
#  'adlog.flurry.com',
#  'physweb.bgu.ac.il',
#  'www.viralfever.biz',
#  'www.mediawiki.org',
#  'p4-etywnujvmvkju-c2glnkeobnux3ral-457142-i1-v6exp3-ds.metric.gstatic.com',
#  'ucbtheatre.com',
#  'videos-h-10.ak.instagram.com',
#  'r6---sn-q4f7dm76.googlevideo.com',
#  'www.telegraph.co.uk',
#  'services.picadmedia.com',
#  'clients3.google.com.ac.il',
#  'r7---sn-aigllm7r.googlevideo.com',
#  'f328f4d4c80KGZEDHHA-nainvshw1429794561-sonar.xx.fbcdn.net',
#  'www.rak.co.il',
#  'p4-edud2us2qnkma-oanctsspphzpo5qo-216635-i1-v6exp3-v4.metric.gstatic.com',
#  'files.bannersnack.com',
#  'www.gadial.net',
#  'ticktick.com',
#  'web.mit.edu',
#  'doctorsonly.co.il',
#  's0.2mdn.net',
#  'www.ezflow.com',
#  'translate.google.co.il',
#  'facebook.com',
#  'www.beetailer.com',
#  'videos-c-18.ak.instagram.com',
#  'external.dmtracker.com',
#  'files2.adme.ru',
#  'www.taimeod.co.il',
#  'www.maya-foods.com',
#  'a.intsig.net',
#  'r15---sn-nx57ynel.gvt1.com',
#  'bl3302files.storage.live.com',
#  'www.queerty.com',
#  'onepush.query.yahoo.com',
#  'pigment-adv.1host.co.il',
#  'adoric.com',
#  'images.vicomi.com',
#  'api.tozelabs.com',
#  'img100-215.xvideos.com',
#  'wikiislam.net',
#  'karaoketv.walla.co.il',
#  'graphics8.nytimes.com',
#  'www.mountofolives.co.il',
#  'scholar.google.co.il',
#  'www.mtvtix.com.au',
#  'mg.yadro.ru',
#  'ru.pornhub.com',
#  'BAYMSGR2012808.gateway.messenger.live.com',
#  'p4-fzklatb2wkgms-ryrlvu5ynwhgprqm-if-v6exp3-v4.metric.gstatic.com',
#  'r6---sn-q0c7dn7k.gvt1.com',
#  'physicsworld.com',
#  '4798106.fls.doubleclick.net',
#  'st.mycdn.me',
#  'cdnbakmi.kaltura.com',
#  'surprises.tango.me',
#  'www.erowid.org',
#  'r10---sn-q0c7dn76.gvt1.com',
#  'r19---sn-q0c7dn7e.googlevideo.com',
#  'aka-cdn-ns.adtechus.com',
#  'dl.dc.ijinshan.com',
#  'smail1009.com',
#  'renderer.qmerce.com',
#  'ak.sail-horizon.com',
#  'fbcdn-video-h-a.akamaihd.net',
#  'maps.lmgtfy.com',
#  'www.czech.cz',
#  'www.assoc-amazon.com',
#  'grownupsgofree.kelloggs.ie',
#  'sucuri.net',
#  'o.twimg.com',
#  'funnygig.com',
#  'p4-c6wntasliuasq-7dxwgvdlrnhnykxy-104495-i1-unicast.metric.gstatic.com',
#  'ib365-1851555667.us-east-1.elb.amazonaws.com',
#  'bigstory.ap.org',
#  'ser.adledge.com',
#  'websitestat.enter-system.com',
#  'dataentry.ynet.co.il',
#  'affiliate-robot.com',
#  '3.bp.blogspot.com',
#  'www.mtv.com.au',
#  'apis.google.com',
#  'www.ecomtrade.co.il',
#  'cmsprod.bgu.ac.il',
#  'svc.m.one.co.il',
#  'r3---sn-cg07luee.googlevideo.com',
#  'img100-479.xvideos.com',
#  'mhomesandproperty.zoopla.co.uk',
#  'topics.nytimes.com',
#  'cld.edg.startappservice.com',
#  'adadvisor.net',
#  'malcolm-prod-swarm.wbplay.com',
#  'trgoals.org',
#  'www.morfix.co.il',
#  'ssl.google-analytics.com.bgu.ac.il',
#  'image.dolphin-browser.cn',
#  'p4-h3tiozzf5xpdy-avpm3inalfp7qbch-if-v6exp3-v4.metric.gstatic.com',
#  'library.osu.edu',
#  'ew1.api.cfpd.bdp.samsung.com',
#  'funny.yo-yoo.co.il',
#  'b.kavanga.ru',
#  'ign-wikis.disqus.com',
#  'secureir.ebaystatic.com',
#  'adrta.com',
#  'topmobile-app.com',
#  'segs.btrll.com',
#  'pixel.prfct.co',
#  'r5---sn-q0c7dn7l.googlevideo.com',
#  'j.mp',
#  'api.asiatone.net',
#  'community.wikia.com',
#  'img100-414.xvideos.com',
#  'my.agoda.com',
#  'qos-prod-bio-dub-common-common.gos.ea.com',
#  'www.orianit.edu-negev.gov.il',
#  'm.studioc.co.il',
#  'videos-g-17.ak.instagram.com',
#  'api.github.com',
#  'adplexmedia.adk2x.com',
#  'img100-326.xvideos.com',
#  'location.gtforge.com',
#  'p4-f2s4hz2pflfja-6cmjy4p64vqeanbw-if-v6exp3-v4.metric.gstatic.com',
#  'platform.twitter.com',
#  'www.fullstory.com',
#  'www.eater.com',
#  'www.wix.com',
#  'p4-bi25v2ucs6jwq-kctldf32su7u5e43-621251-i1-v6exp3-v4.metric.gstatic.com',
#  'r9---sn-4g57km7z.googlevideo.com',
#  'ic.3648339c.0de076.6.c3605.d.rncdn3.com',
#  'dailycaller.com',
#  '231.154.179.212.in-addr.arpa',
#  't.mobitrk.com',
#  'img100-502.xvideos.com',
#  'api.tapuz.co.il',
#  'r18---sn-q0c7dn7l.googlevideo.com',
#  '608-events.olark.com',
#  'dmp.adform.net',
#  'gc.ds.duapps.com',
#  'files4.adme.ru',
#  'res.media.net',
#  'urlauth.ksmobile.net',
#  'communabuilder.tapuz.co.il',
#  'mentad.com',
#  'bus.mosko.mobi',
#  'mmv682.whatsapp.net',
#  'img100-318.xvideos.com',
#  'thepiratebay.se',
#  'cdn.downdetector.com',
#  'www.ew.com',
#  'findnsave.sfgate.com',
#  'astrateg.co.il',
#  'images.starpulse.com',
#  'www.tiredeal.co.il',
#  'd3biamo577v4eu.cloudfront.net',
#  's7.vzw.com',
#  'www.arosport.co.il',
#  'www.ibiblio.org',
#  'front.facetz.net',
#  'img100-043.xvideos.com',
#  'foto-recepti.ru',
#  'studate.bgu.co.il',
#  'in.metamx.com',
#  'ads.trafficpoizon.com',
#  'i4.sndcdn.com',
#  'ip-science.thomsonreuters.com',
#  'ios-app-config.media-imdb.com',
#  'img100-044.xvideos.com',
#  'www.sitehood.co.il',
#  'www.protalix.co.il',
#  'nidal.tv',
#  'www.osef.co.il',
#  'pixel.ani-view.com',
#  'maarivonline.disqus.com',
#  '67.210.58.216.in-addr.arpa',
#  'a899e037f69f12bff9ed41975c1be64a3.profile.waw50.cloudfront.net',
#  'www.he.israelguidedog.org',
#  'us16.zopim.com',
#  'ic.3648339c.003979.6.c3605.d.rncdn3.com',
#  'p4-fzklatb2wkgms-ryrlvu5ynwhgprqm-916124-i2-v6exp3-v4.metric.gstatic.com',
#  'www.ninds.nih.gov',
#  'kick.live.net.il',
#  'intractability.princeton.edu',
#  'www.cchr.org.il',
#  'direct.revsci.net',
#  'besttv2.cdn.it.best-tv.com',
#  'p4-az5pjpwkzcbny-sojmdwrfcsdzgx7f-923172-i1-v6exp3-ds.metric.gstatic.com',
#  'data.nba.com',
#  '3-edge-chat.facebook.com',
#  'browser-update.org',
#  'tags.walla.co.il',
#  'gamethrive.com',
#  'events.frwrd.me',
#  '40.media.tumblr.com',
#  'api.entrance.sonymobile.com',
#  'ausiellofiles.ew.com',
#  'www.kelloggs.co.uk',
#  'scontent-b-fra.xx.fbcdn.net',
#  'dwi.d.weather.com',
#  'www.lyricsfreak.com',
#  'crt13.b1.cdn.co.il',
#  'stats.ibtimes.co.uk',
#  'cdn1.image.keezmovies.phncdn.com',
#  'superitch.com',
#  'www.pureexample.com',
#  'beacon-eu.rubiconproject.com',
#  'p4-ek72ykvaqivls-wk4yqcgz2umzvs7z-if-v6exp3-v4.metric.gstatic.com',
#  'isrageo.blogspot.com',
#  'scienceworld.wolfram.com',
#  '65524.0.3.5.20703.rst5.r.skype.net',
#  '7590.api-03.com',
#  'wpcomwidgets.com',
#  'mmv244.whatsapp.net',
#  'xwne.wcdn.co.il',
#  'papi.my6sense.com',
#  'metrics.electusdigital.com',
#  'www.cal-online.co.il',
#  'www.sapir-aguda.co.il',
#  'tickets.ticket4u.co.il',
#  'us32.zopim.com',
#  'www.ons.gov.uk',
#  'videos-a-19.ak.instagram.com',
#  'img100-701.xvideos.com',
#  'dsn3.d.skype.net',
#  'www.shichor.co.il',
#  'egged.co.il',
#  'p4-h5qszb4l4e5z6-yf4i3cd636cxm7iz-558497-i2-v6exp3-ds.metric.gstatic.com',
#  'ads.medlheads.com',
#  'im.36483300.56a987a.ads.a4cdn.contentabc.com',
#  'koora720comchat.chatango.com',
#  'eo.wikipedia.org',
#  'ads.ilykefunny.com',
#  'www.derech-haim.co.il',
#  'i1.services.social.microsoft.com',
#  'p4-h6qjefapfn572-6ubj4c5zsv55iqdi-420867-i2-v6exp3-ds.metric.gstatic.com',
#  'vordu.co.il',
#  'my.mail.ru',
#  'r3---sn-cg07luer.googlevideo.com',
#  'www.nytimes.com',
#  'adblockplus.org',
#  't4ft.de',
#  'sharethis.com',
#  'media.wakavision.com',
#  'az361816.vo.msecnd.net',
#  'api.facebook.com',
#  'd12i351y3swd4r.cloudfront.net',
#  'www.pashbar.co.il',
#  'www.hwbot.org',
#  'ner.izkor.mod.gov.il',
#  'atmamos.alicdn.com',
#  'img100-106.xvideos.com',
#  'shopvac.cyngn.com',
#  'www.statesymbolsusa.org',
#  'www.chelationtherapyonline.com',
#  'video-ams2-1.xx.fbcdn.net',
#  'veg.anonymous.org.il',
#  'r10---sn-q0c7dn7l.googlevideo.com',
#  'action1.adit-media.com',
#  'media.data-slimspots.com',
#  'sync.mathtag.com',
#  'impact.applifier.com',
#  'mmv615.whatsapp.net',
#  'www.idi.org.il',
#  '3967926.fls.doubleclick.net',
#  'r6---sn-cg07luer.googlevideo.com',
#  'news2.scepia-sites.co.il',
#  'kbd.data.kpns.ijinshan.com',
#  'ae.ktuvit.com',
#  'r15---sn-5hneznel.googlevideo.com',
#  'www.sdarot.biz',
#  'widget.nanorep.com',
#  'a.rtb.grvcdn.com',
#  'creative.ad120m.com',
#  'upload-community.kipa.co.il',
#  'www.knowledge4all.co.il',
#  'static-avc.lglime.com',
#  'sony-entrance-sp-proxy.appspot.com',
#  '42.217.209.125.in-addr.arpa',
#  'duapps.com',
#  'track.mct.moblin.com',
#  'static.adikastyle.com',
#  'ws-ext.nana10.co.il',
#  'static-m.u6346p5933.ilykefunny.com',
#  'www.alp.co.il',
#  'p4-fku7x76rc5cws-zjneyxhmfl77rye4-977070-s1-v6exp3-v4.metric.gstatic.com',
#  'www.cff.org',
#  'api.worldnow.com',
#  'r2---sn-nwj7km7r.gvt1.com',
#  'mmi607.whatsapp.net',
#  'www.patreon.com',
#  'p4-fpy63paas2olo-emoglqzp4py4ep4j-809119-s1-v6exp3-v4.metric.gstatic.com',
#  'ok.ru',
#  'us.account.samsung.com',
#  'p4-cavvpbc2kbwas-qgywqmbo3fbsdofz-140622-s1-v6exp3-v4.metric.gstatic.com',
#  'www.linkedin.com',
#  '94.195.125.74.in-addr.arpa',
#  'rep.erate.co.il',
#  'st0.vk.me',
#  'www.entradas.com',
#  '137.60.193.54.in-addr.arpa',
#  'links.a.co.il',
#  'usabursa.co.il',
#  'b1.zemanta.com',
#  'www.sugat.com',
#  'www.systematics.co.il',
#  'www.ctt.pt',
#  'info.yl-invest.co.il',
#  'bss.allshareplay.com',
#  'm.nydailynews.com',
#  'p4-fhosiecdmffny-rdu6tyaiwiwzjo7z-563621-s1-v6exp3-v4.metric.gstatic.com',
#  'www.soe.ucsc.edu',
#  'gameconnexions.com',
#  'stat.enter-system.com',
#  'fast.mtvn.demdex.net',
#  'tvbythenumbers.zap2it.com',
#  'emea-istrien.netmng.com',
#  'cs.meltdsp.com',
#  'qos-prod-bio-iad-common-common.gos.ea.com',
#  'www.amazon.co.uk',
#  'm.behatsdaa.org.il',
#  'lifestyle.nana10.co.il',
#  'b.scorecardresearch.com',
#  'www.silestone.co.il',
#  'www.doctors.co.il',
#  'ts1.mm.bing.net',
#  'player.ooyala.com',
#  'mp.weixin.qq.com',
#  'com.imangi.s3-website-us-east-1.amazonaws.com',
#  'www.aradon.co.il',
#  'www.fxp.co.il',
#  'www.tamlil2100.co.il',
#  '139.120.202.10.in-addr.arpa',
#  'api.amplitude.com',
#  'r5---sn-q0c7dn7d.gvt1.com',
#  'i.w55c.net',
#  'www.stoliart.co.il',
#  'widgets.ign.com',
#  'gs1.wac.edgecastcdn.net',
#  'www.mwredman.com',
#  'p4-dghageiot3y4m-5jgjgszwv6cyg5na-482792-s1-v6exp3-v4.metric.gstatic.com',
#  'www.newscientist.com',
#  'gallery.mailchimp.com',
#  '9gag.tv',
#  'shealth-image.samsunghealth.com',
#  'goupdate.3g.cn',
#  'www.pinat-hay.com',
#  'r8---sn-q0c7dn76.googlevideo.com',
#  'p4-d2gapax4kkk5s-k73xplt7idp7elqx-104775-i1-unicast.metric.gstatic.com',
#  'besttv29.cdn.it.best-tv.com',
#  'demonstrations.wolfram.com',
#  'adtrack.king.com',
#  'images.ak.instagram.com',
#  'mmv243.whatsapp.net',
#  'a2.opinionstage-res.cloudinary.com',
#  'mikzoan.sherut100.net',
#  'p4-cdkl3oz2sxn7o-u3lfkjgtcdlnczhs-if-v6exp3-v4.metric.gstatic.com',
#  'hadusky.co.il',
#  'allmyvideos.net',
#  'petnet.co.il',
#  'kampai.inforu.mobi',
#  'www.evolo.us',
#  'www.mgo.visionbox.co.il',
#  'r19---sn-vgqs7n7s.googlevideo.com',
#  'www.mophie.com',
#  'cdn.optimizely.com',
#  'r19---sn-aigllnlr.googlevideo.com',
#  'thumbnails-02.gp-static.com',
#  'img100-789.xvideos.com',
#  'hn.inspectlet.com',
#  'www.dogslife.org.il',
#  'impie.tradedoubler.com',
#  'www.wallatours.co.il',
#  'cyber.calcalist.co.il',
#  'secure-uk.imrworldwide.com',
#  'youzanporn.com',
#  '2.158.220.66.in-addr.arpa',
#  '8ca6a693.api.splkmobile.com',
#  'dailyliked.net',
#  'm.wsj.net',
#  'api.skype.com',
#  'www.insertlifehere.net',
#  'images.applicaster.com',
#  'www.cs.sunysb.edu',
#  'r10---sn-q0c7dn7e.googlevideo.com',
#  'at.alenty.com',
#  'yandex.st',
#  'r11---sn-q0c7dn7l.gvt1.com',
#  'www.eza.co.il',
#  'r14---sn-q0c7dn76.googlevideo.com',
#  'ad.sxp.smartclip.net',
#  'cd.lenzmx.com',
#  'mmv214.whatsapp.net',
#  't.mookie1.com',
#  'mmi645.whatsapp.net',
#  'cdn.feeds.videosz.com',
#  'trophy01.np.community.playstation.net',
#  'tracker.veryamt.com',
#  'www.redbulletin.com',
#  'www.betfair.com',
#  'r8---sn-o097zuez.googlevideo.com',
#  'ad.directrev.com',
#  'www.cardcom.co.il',
#  'www.mooviees.com',
#  'track.hubspot.com',
#  'affiliate.integral-marketing.com',
#  'www.campaigns.hotnet.net.il',
#  'ei.rlcdn.com',
#  'gs.mindjolt.com',
#  '216.112.194.173.in-addr.arpa',
#  'overhaps.com',
#  'compare-consumer-reviews.com',
#  '0.US.pool.ntp.org',
#  'nahaldarga.org.il',
#  'p4-fpy63paas2olo-emoglqzp4py4ep4j-if-v6exp3-v4.metric.gstatic.com',
#  'h.live.com',
#  'hiname.co',
#  'c.go-mpulse.net',
#  'www.valigar.com',
#  'd.adroll.com',
#  'www.leg.state.mn.us',
#  'cs.microsoft.com',
#  'videos-d-2.ak.instagram.com',
#  'recon-ecc.aws-protocol-testing.com',
#  'm.frogi.co.il',
#  'motileybel.files.wordpress.com',
#  '90.118.89.54.in-addr.arpa',
#  'r3---sn-q4f7dm7k.gvt1.com',
#  'spo55ru.blogspot.com',
#  'et.w.inmobi.com',
#  'r5---sn-vgqsem76.gvt1.com',
#  'uk.finance.yahoo.com',
#  'css.opposingviews.com',
#  'imap.gmail.com',
#  'woodstockfestival.pl',
#  'mackeeperapp.mackeeper.com',
#  'p4-hud2wn4q2xubm-2cuzaz5gfj2wxtjf-281080-i1-v6exp3-ds.metric.gstatic.com',
#  'mrtb-nj.lfstmedia.com',
#  'casale-cm.p.veruta.com',
#  'cdn.flipboard.com',
#  'r14---sn-q0c7dn7y.gvt1.com',
#  'www.bubulu.net',
#  'www.ticketingcentral.com',
#  'sync2.adsniper.ru',
#  'files5.adme.ru',
#  'www.trackimpression.com',
#  'www.egged-taavura.co.il',
#  'aristo4bgu.bgu.ac.il',
#  'p4-e3w73tejvow5o-hxfky6yuobi46qfl-408144-s1-v6exp3-v4.metric.gstatic.com',
#  'www.marvel.com',
#  'davidson.weizmann.ac.il',
#  'www.studioc.co.il',
#  'www.19actionnews.com',
#  'hamadrich.idc.ac.il',
#  'nmsites.nextopic.com',
#  'r2---sn-4g57kuel.googlevideo.com',
#  'www.zoomd.com',
#  'i61.tinypic.com',
#  'go.microsoft.com',
#  'r8---sn-q4f7dm7k.googlevideo.com',
#  'newsstand.googleusercontent.com',
#  'freecrochetpattern.weebly.com',
#  'videos-h-15.ak.instagram.com',
#  'r14---sn-a5mekm7k.gvt1.com',
#  'p4-cji4je5dhkqzg-7lble6oiw3q47xaa-if-v6exp3-v4.metric.gstatic.com',
#  'ttsgw.world.waze.com',
#  'www.blastr.com',
#  'mmv285.whatsapp.net',
#  'appnext-a.akamaihd.net',
#  'r6---sn-ab5e6m7e.googlevideo.com',
#  'r11---sn-4g57kndk.googlevideo.com',
#  'securedrop.theguardian.com',
#  'incoming.cloud-trax.com',
#  'heavy.com',
#  'www.bgu.co.il',
#  'resources.kiosked.com',
#  'wallofcoins.com',
#  '03c17a9.netsolhost.com',
#  'www.novisign.co.il',
#  'checkout.google.com',
#  'secure.pow7.com',
#  'live.sekindo.com',
#  'www.cbsinteractive.com',
#  'www.yourtango.com',
#  'www.yes.co.il',
#  'sp.fastclick.net',
#  'p4-fny2hunvvy7ou-lsgv5t5akhdx5loy-989180-i2-v6exp3-v4.metric.gstatic.com',
#  'www.winwin.co.il',
#  'www.behatsdaa-nadlan.com',
#  'visit.maccabi4u.co.il',
#  'd1fnuwuy1vks2k.cloudfront.net',
#  'forms.verizonwireless.com',
#  'mmv279.whatsapp.net',
#  'www.mouse.co.il',
#  'community.videogamer.com',
#  'af-gb.mgid.com',
#  'm.jerusalem.azrieli.com',
#  'www.seat.co.il',
#  'www.megalim.co.il',
#  'www.xn--4dbdhcduba8b8cxbf.net',
#  '487-events.olark.com',
#  'api.instagram.com',
#  'r13---sn-a5m7znez.googlevideo.com',
#  'encarta.msn.com',
#  'attachment.fbsbx.com',
#  'geo.widdit.com',
#  'videos-c-10.ak.instagram.com',
#  'analytics.revee.com',
#  'direct.tranzila.com',
#  'ads.ad4game.com',
#  'cms.quantserve.com',
#  'r3---sn-q0c7dn7s.googlevideo.com',
#  'files3.adme.ru',
#  'cdn1.media.trafficjunky.net',
#  'he.urbandictionary.com',
#  'm.quantcount.com',
#  'tr.urbandictionary.com',
#  'videos-d-11.ak.instagram.com',
#  'content.dictionary.com',
#  'www.todaysiphone.com',
#  'static.arcgis.com',
#  'upoll.umengcloud.com',
#  'poalot.com',
#  'w3server.t17service.com',
#  'r1---sn-cg07luel.googlevideo.com',
#  'pop.bleacherreport.com',
#  'ss7.vzw.com',
#  'locksmithcourse.ravpage.co.il',
#  '36.media.tumblr.com',
#  'p4-auwgyrf2h2qec-fhe4v2th46fs5cbd-198638-i1-v6exp3-ds.metric.gstatic.com',
#  'easy.co.il',
#  'www.third-ear.com',
#  'www.trbimg.com',
#  'android.clients.google.com.bgu.ac.il',
#  'www.tri-max.co.il',
#  'qos-prod-bio-sjc-common-common.gos.ea.com',
#  'auth.np.ac.playstation.net',
#  'www.raycommedia.com',
#  'mmv288.whatsapp.net',
#  'www.tellows.com',
#  'instagramimages-a.akamaihd.net',
#  'www.maccabi-tlv-shop.co.il',
#  'mmv215.whatsapp.net',
#  'ais-api.applicaster.com',
#  'iheartdogs.com',
#  'ko.wikipedia.org',
#  'p4-etywnujvmvkju-c2glnkeobnux3ral-457142-s1-v6exp3-v4.metric.gstatic.com',
#  'aloha.viber.com',
#  'theforma.myshopify.com',
#  'img100-405.xvideos.com',
#  'es.uefa.com',
#  'www.wellingtonsecurity.net',
#  'videos-d-14.ak.instagram.com',
#  'boots.scene7.com',
#  'www.thc.org.il',
#  'www.sexmovie.co.il',
#  'ipango.itip.co.il',
#  'shironet.mako.co.il',
#  'shop.eurovision.tv',
#  '115.2.250.178.in-addr.arpa',
#  'bmaeu.badoo.com',
#  'dictionary.reference.com',
#  'www.hefty.co',
#  'router.infolinks.com',
#  'r20---sn-q0c7dn7s.googlevideo.com',
#  'www.valigar.co.il',
#  'scripts.kissmetrics.com',
#  'srv.exposebox.com',
#  'join-talent.com',
#  'openjobs.co.il',
#  'www.onlineadsnetwork.com',
#  'r16---sn-q0c7dn7l.gvt1.com',
#  'poll.walla.co.il',
#  'html5shiv.googlecode.com',
#  'r5---sn-cg07luek.googlevideo.com',
#  'p.jango.com',
#  'banners1.bizportal.co.il',
#  'img.mediaplex.com',
#  'd4757.allmyvideos.net',
#  'yeda.bgu.co.il',
#  'api.facebook.com.ac.il',
#  'cdn.kixer.com',
#  'gwc.lphbs.com',
#  'www.fcbarcelona.com',
#  'therealstanlee.com',
#  'dt.scanscout.com',
#  'seethisinaction.com',
#  'videos-a-5.ak.instagram.com',
#  'www.htc.com',
#  'www.jewishjournal.com',
#  'fbcdn-vthumb-a.akamaihd.net.bgu.ac.il',
#  'local.chron.com',
#  'www.preventionweb.net',
#  'cluster18b.heavy-r.com',
#  'uc.cm.ksmobile.com',
#  'login.dotomi.com',
#  'p4-gkbmv6ehvsgha-qkmpeqhw2yvg5yf3-532964-s1-v6exp3-v4.metric.gstatic.com',
#  'www.reidman.co.il',
#  's.aolcdn.com',
#  'fashionforward.mako.co.il',
#  'c.t4ft.de',
#  'dx0qysuen8cbs.cloudfront.net',
#  'mxnet.ynet.co.il',
#  'distilleryvesper3-15.ak.instagram.com',
#  'adserver.adtechus.com',
#  'device.4seeresults.com',
#  'ht.cdn.turner.com',
#  'ar.thomsonreuters.com',
#  'www.dakotayeast.com',
#  'www.listandtell.co.il',
#  'atp.mxptint.net',
#  'by.uservoice.com',
#  's3.amazonaws.com.bgu.ac.il',
#  'blogs.sonymobile.com',
#  'www.streamnowmovies.com',
#  'img3.yiwutalk.com',
#  's.ad135m.com',
#  'www.rivitmedia.com',
#  'da.wikipedia.org',
#  'www.red-fans.com',
#  'plus.google.com',
#  'www.eonline.com',
#  'data.bnf.fr',
#  'mediadownload.calcalist.co.il',
#  'android.googleapis.com',
#  'www.comicbookresources.com',
#  'p4-boeztdr7ljnio-jd7tfqijiecosz3a-602670-i2-v6exp3-v4.metric.gstatic.com',
#  'happykitchenil.files.wordpress.com',
#  'www.qq.com',
#  'www.wobi.co.il',
#  'r6---sn-hp57knlr.googlevideo.com',
#  'mobile.askpeople.co.il',
#  'r3---sn-p5qlsnsk.googlevideo.com',
#  'math1.cet.ac.il',
#  'samsungbuiasr.vlingo.com',
#  'mazaltov.walla.co.il',
#  'img5.timeinc.net',
#  'ads.creative-serving.com',
#  'www.eurovision.tv',
#  'wims.unice.fr',
#  'www.translatesonline.com',
#  'www.pc.co.il',
#  'www.hear.org',
#  'sslstatic.wix.com',
#  'r18---sn-ab5e6m7l.googlevideo.com',
#  'secure.opinionlab.com',
#  'adclick.g.doubleclick.net',
#  'ready.org.il',
#  'p4-dgpambceyjtlu-rzp6motgb4v5h5vz-348958-i2-v6exp3-v4.metric.gstatic.com',
#  'api.sherut.net',
#  'cdn.thumbs.roadshamer.com',
#  'www.iphonezone.co.il',
#  'www.math.nmsu.edu',
#  'downloads.mailchimp.com',
#  'comlead.net',
#  'cosu.sonymobile.com',
#  'sock55.pusher.com',
#  '62296.0.2.5.20703.rst1.r.skype.net',
#  'www.yl-invest.co.il',
#  'img100-312.xvideos.com',
#  'www.filmon.com',
#  'il-prof.np.community.playstation.net',
#  'portal.k12.il',
#  'bn1files.storage.msn.com',
#  'cas.pxl.ace.advertising.com',
#  'www.blogtopsites.com',
#  'israel.thebeehive.org',
#  'www.showoff.co.il',
#  'www.amazon.de',
#  'r9---sn-vgqsem7z.googlevideo.com',
#  'r8---sn-q0c7dn7z.gvt1.com',
#  'ja.wikipedia.org',
#  'www.goldtip.co.il',
#  'viva.walla.co.il',
#  'www.calcalist.co.il',
#  'r1---sn-h5jic5-ua8e.gvt1.com',
#  'dquery.neto.co.il',
#  'b.thumbs.redditmedia.com',
#  'cdn.ctnsnet.com',
#  'gld.push.samsungosp.com',
#  'gl.wikipedia.org',
#  'healthy.walla.co.il',
#  'iriya.bgu4u.co.il',
#  'ads2.contentabc.com',
#  'static.viralnova.com',
#  '195.194.18.50.in-addr.arpa',
#  'api-ak3.wunderground.com',
#  'search.midomi.com',
#  'www.thisis50.com',
#  'news.walla.co.il',
#  'p4-af5yseze3kn2s-7a65jhee6vwhai6c-789789-s1-v6exp3-v4.metric.gstatic.com',
#  'sb.freeskreen.com',
#  'bruce.orel.ws',
#  'p4-enc7wfybxaasa-zkg6dyfbzaousdg3-447489-s1-v6exp3-v4.metric.gstatic.com',
#  'project.saatchi-interactive.co.il',
#  'chart.apis.google.com',
#  'tickets.b7t.co.il',
#  'conversions.adaptv.advertising.com',
#  'r4---sn-p5qlsnsy.googlevideo.com',
#  'sftimes.s3.amazonaws.com',
#  'kraken-measurements.s3.amazonaws.com',
#  'farm4.static.flickr.com',
#  'mortalkombat.wikia.com',
#  'portal.manjushri.alibaba.com',
#  'eventsalt30.adcolony.com',
#  'makinggamesisfun.co.uk',
#  'umano.me',
#  'www.dailytelegraph.com.au',
#  'www.qualtrics.com',
#  'vap2dfw1.lijit.com',
#  '2-edge-chat.facebook.com',
#  'www.predictad.com',
#  'p4-fyoduiwf5euba-waxbnkjxwb723vqr-if-v6exp3-v4.metric.gstatic.com',
#  'www.sniper-m.com',
#  'distilleryimage6.ak.instagram.com',
#  '0.client-channel.google.com',
#  'www.bus.co.il',
#  'www.skyscanner.no',
#  'csdl.engin.umich.edu',
#  'de16.zopim.com',
#  'flix.tapuz.co.il',
#  'server.cappsool.com',
#  'lb-wdc.mdotm.co',
#  'thumbnails-04.gp-static.com',
#  'sonymobile-sc-fb-like-config.s3.amazonaws.com',
#  'ps15.pubnub.com',
#  'p4-capr2jiu5cw6c-cxd553pz2zdkywcv-if-v6exp3-v4.metric.gstatic.com',
#  'videos-f-8.ak.instagram.com',
#  'm.hotmail.com',
#  'twitpic.com',
#  'adservices.picadmedia.com',
#  'join.yes.co.il',
#  'profile.localytics.com',
#  'www3.interscience.wiley.com',
#  'c1.navrcholu.cz',
#  'srx.main.ebayrtm.com',
#  'www.forom.ws',
#  'by3301files.storage.live.com',
#  'mmv223.whatsapp.net',
#  'ads.adsonar.com',
#  'mavir.co.il',
#  'news-front.info',
#  'r3---sn-cg07lue6.googlevideo.com',
#  'aa-gb.mgid.com',
#  'videos-a-11.ak.instagram.com',
#  'fellows.acm.org',
#  'api.vungle.com',
#  'staff.jccc.net',
#  'histclo.com',
#  'ggimg.tapas.net',
#  'cdn.iheartsecret.com',
#  'gateway.ea.com',
#  'api.dmcdn.net',
#  'r16---sn-ab5l6nee.googlevideo.com',
#  'passionfruitads.s3.amazonaws.com',
#  'static.rottentomatoes.com',
#  'd2ymkpxi1rgldj.cloudfront.net',
#  'heydrichr.blogspot.co.il',
#  'www.chinabuy.co.il',
#  'rover.ebay.com',
#  'mmv303.whatsapp.net',
#  'pr-bh.ybp.yahoo.com',
#  'forms.gov.il',
#  'mmi627.whatsapp.net',
#  'www.parter.ru',
#  'segments.wt-data.com',
#  'explore.bfi.org.uk',
#  'benshahar.wix.com',
#  'www.hapoelb7.co.il',
#  'adxhm.d.chango.com',
#  'contentz.mkt2732.com',
#  'www.shufersalblog.co.il',
#  'tolkiengateway.net',
#  'topoffer.mobi',
#  'cdn1.clkrev.com',
#  'ads.trafficjunky.net',
#  'ad6e42d0971d1df653b52d4b02bbc7469.profile.mnl50.cloudfront.net',
#  'www.dailymail.co.uk',
#  'cdn.petametrics.com',
#  'www.supersize.co.il',
#  'distilleryvesper6-2.ak.instagram.com',
#  'blog.012.net',
#  'www.ynet.co.ilwww.calcalist.co.il',
#  'archive.southwalesguardian.co.uk',
#  'bks2.books.google.com',
#  'www1066.mdotm.com',
#  'manager.spotgam.es',
#  'csbi.htcsense.com',
#  'www.nifgashim.net',
#  'p4-d5wsxdls3bqus-u5wpitzst4qjbnv5-759726-i1-v6exp3-ds.metric.gstatic.com',
#  'r10---sn-q0c7dn7z.googlevideo.com',
#  'sl.doctorim.co.il',
#  'calcalist.the-insider.co.il',
#  'logc405.xiti.com',
#  'www.mayachen.co.il',
#  'cdn2.digitaltrends.com',
#  'diply.com',
#  'ayalim.org.il',
#  'kona5.kontera.com',
#  'www.tatranmusic.com',
#  'pixel.moatads.com',
#  'edge.quantserve.com',
#  '31.217.209.125.in-addr.arpa',
#  'p4-e5gm3ufjqxnwa-kolfymmsvau2bbp2-209229-i1-v6exp3-v4.metric.gstatic.com',
#  'prognathous.mail-central.com',
#  'sso.zap.co.il',
#  'api.houzz.com',
#  'www.sportfluff.com',
#  'static.entrance.sonymobile.com',
#  'serve.omni-ads.com',
#  'www.bgu.ac.il',
#  '186.81.59.108.in-addr.arpa',
#  'static.amazon.com',
#  'video.google.com',
#  'p4-c7czwc75ozhya-vafwzdq5mlznr7hh-if-v6exp3-v4.metric.gstatic.com',
#  'r10---sn-nwj7knes.googlevideo.com',
#  'stage-a.applovin.com',
#  'videos-d-4.ak.instagram.com',
#  'us46.zopim.com',
#  'www.adidas.co.il',
#  'go.mobilix.eu',
#  'mediaserver.bgu.ac.il',
#  'trk.bidtrk.com',
#  'twitter.com',
#  'www.goshow.co.il',
#  'us20.zopim.com',
#  'a650.casalemedia.com',
#  'p4-afspqwasiukii-ida2e6uwlos6iyd2-if-v6exp3-v4.metric.gstatic.com',
#  'rhtag.com',
#  'img100-877.xvideos.com',
#  'ad1.adit-media.com',
#  'p4-budcds3hce3fk-223tm4ypvteukl5q-882144-s1-v6exp3-v4.metric.gstatic.com',
#  'tapstream.tapatalk.com',
#  'p.d41.co',
#  'img6a.flixcart.com',
#  'g.alicdn.com',
#  'beacons.gvt2.com',
#  'r1---sn-q0c7dn7y.googlevideo.com',
#  'api.linkedin.com',
#  'mmi216.whatsapp.net',
#  'wa.vodafone.ie',
#  'r6---sn-cg07luee.googlevideo.com',
#  'sjc-uhls-proxy06.ustream.tv',
#  'content.pollonize.com',
#  'spring14.gosredirector.ea.com',
#  'e1.static.hoptopboy.com',
#  'mmi110.whatsapp.net',
#  'usa.autodesk.com',
#  'r6---sn-hp57kn7e.googlevideo.com',
#  'serve.qriously.com',
#  'g1.globo.com',
#  'click4.truecaller.com',
#  'a338.casalemedia.com',
#  'mmi226.whatsapp.net',
#  'r7---sn-q0c7dn7s.googlevideo.com',
#  'nist1-lnk.binary.net',
#  'mobile.bankleumi.co.il',
#  'www.claymath.org',
#  'orionimg.adkmob.com',
#  'p4-hosak5vmgy456-z3txqjpx7wxempke-845190-s1-v6exp3-v4.metric.gstatic.com',
#  'cdn.theguardian.tv',
#  'goviralengine.cloudapp.net',
#  'p4-ak2ihynhvlebw-amnb7ktaoxl55nck-960819-i2-v6exp3-ds.metric.gstatic.com',
#  'libs.de.coremetrics.com',
#  'gi-israel.info',
#  'videos-c-19.ak.instagram.com',
#  'www.ishim.co.il',
#  'videos-e-13.ak.instagram.com',
#  'geektyrant.com',
#  'speedtestgz.hadara.ps',
#  'clients3.google.com',
#  'img100-949.xvideos.com',
#  '20.346ab3474261484093a145656974f92c.app.ktcfg.net',
#  'pubservcdn.picadmedia.com',
#  'static-resource.np.community.playstation.net',
#  'gentlebarn.org',
#  'clients4.google.com',
#  'sex4free.co.il',
#  '2.pool.ntp.org',
#  'security.bgu.ac.il',
#  'www.hellotravel.com',
#  'i.ctnsnet.com',
#  'adb.adledge.com',
#  'ar.wikipedia.org',
#  'r1---sn-cg07lued.googlevideo.com',
#  'lt.wikipedia.org',
#  'r4---sn-cg07luel.googlevideo.com',
#  'ip.casalemedia.com',
#  'scontent.cdninstagram.com',
#  'network.adsmarket.com',
#  'r4---sn-cg07luee.googlevideo.com',
#  'bdv.bidvertiser.com',
#  'cdn1a.static.pornhub.phncdn.com',
#  'p4-cx356fjqz3kom-lv5agz4jgn5gsin2-963023-i1-v6exp3-v4.metric.gstatic.com',
#  'ec01.cooladata.com',
#  'gaby1.hit.gemius.pl',
#  'nl.youporn.com',
#  'www.homie.co.il',
#  'mytm.nrg.co.il',
#  'mmv249.whatsapp.net',
#  'i1-j4-18-6-1-13960-3719423837-s.init.cedexis-radar.net',
#  'www.ims.gov.il',
#  'my.ynet.co.il',
#  'www.canneszions.com',
#  'r19---sn-q0c7dn7s.gvt1.com',
#  'www.messi2day.com',
#  'textologia.net',
#  'providence.voxmedia.com',
#  'xtrapath2.izatcloud.net',
#  'www.citypay.co.il',
#  'd29oav93j91bc6.cloudfront.net',
#  'suwidget3.sphereup.com',
#  'videos-h-6.ak.instagram.com',
#  'seattleclouds.com',
#  'demilked.disqus.com',
#  'flr5.cbox.ws',
#  ...}

# %%
suspicious_domains
# Out:
# {'hjijplvcblqun',
#  'tdwiqlwplrjqj',
#  'ujckfbdepynvpxk',
#  'seuyrwcems',
#  'sezuecy',
#  'twsfcslpepma',
#  'iugbjexbj',
#  'hsegvrkakuf',
#  'yvgvzmr',
#  'zbmqccedqby',
#  'znkdajf',
#  'jjaelrex',
#  'uncfeqwnhnrb',
#  'wcxjxhdde',
#  'cdmvmnilsdd',
#  'yrixwykz',
#  'drvzwmh',
#  'ebbtfmkbjhsmnfd',
#  'muautqtcoisjwf',
#  'dipxrjucdnw',
#  'exdxgzw',
#  'qyupdniyvn',
#  'gkfmzsc',
#  'pzrrjht',
#  'mueqhgccffx',
#  'gyozrvefavwnmk',
#  'nciyuaxbitt',
#  'pghhteo',
#  'gytsrouiz',
#  'dqzlldnrtxoeki',
#  'xsexyqeh',
#  'oyyjmuvhqznbf',
#  'zqhyhrtwaxckrnn',
#  'vkbtbanpdkogd',
#  'clgqpblwnnpqws',
#  'ubngwok',
#  'omdtwtmemzpd',
#  'wfwekuuxtgpbgpd',
#  'ggtwdbcnoav',
#  'otlzpskvnt',
#  'zkkcjcidykyz',
#  'pzmcehktui',
#  'vvhydbvtrnussiu',
#  'yyxrghvizyh',
#  'rucygethzhdpekw',
#  'cyldfogky',
#  'szgvrhcn',
#  'bswerjis',
#  'hudgzdshnysvgdo',
#  'phqbqusdmgke',
#  'dyralfgbtm',
#  'jxuuosirigshgxo',
#  'xybbuhxmjoxkf',
#  'esdzdaubvyogn',
#  'gydpjevxmwqn',
#  'oddborqhlda',
#  'aygltbbekvjhzg',
#  'ehwxqtleait',
#  'qvpcxxoxnxtmjf',
#  'kviiguxaskr',
#  'mkgnjrfyjxsnhac',
#  'mkghgfkmdxod',
#  'swexwrgieopqr',
#  'fhkdgxnko',
#  'ggdqufqppdemhdg',
#  'thxwiqip',
#  'sfzdbcsbhfxznn',
#  'fxxayxtnwewba',
#  'imgllxl',
#  'cpytqljh',
#  'pczlvrnazdgvn',
#  'vtvhpas',
#  'hpxspgil',
#  'opzfstpaq',
#  'rfrqnftdmxjmr',
#  'eahsyir',
#  'plwbbwckrfge',
#  'palhjfzerchek',
#  'vtkeeikrdr',
#  'gezpjpcvwigqz',
#  'vxchjqzwlodvvw',
#  'grrnvdwf',
#  'hzfcblm',
#  'mskrnyqvl',
#  'knarklpfiw',
#  'wsegjgosvd',
#  'iditurdfid',
#  'ogrvvpbuybk',
#  'dunorangfkcalqc',
#  'paanufgrdl',
#  'wastwlc',
#  'rmcnhrdnctbbyqh',
#  'eflyvlafohlpw',
#  'npfixyanib',
#  'itktrpnradqm',
#  'iuurkrxnkxsa',
#  'pknapdseyzl',
#  'zecoosnyf',
#  'adqvzbgq',
#  'betrofbyvgmfm',
#  'duyrbjdicy',
#  'pvpibinb',
#  'mezqytcfecc',
#  'beazeqqmpl',
#  'hbvotubhp',
#  'hasswqempbbuebu',
#  'ydppbhcr',
#  'ruywcjwgji',
#  'wtewrlvcdkdkhha',
#  'rekmhixi',
#  'qglfnogb',
#  'zhwfwhkllkmpq',
#  'fdfevfbsmqvywi',
#  'fzqzxkdog',
#  'ylvkrbahrlvsa',
#  'iipzghljsbt',
#  'mavdkyzppnhcx',
#  'bfmyjeu',
#  'xkkrpxii',
#  'oazmjmnn',
#  'azcxkjpijvz',
#  'xsqlejycnmkn',
#  'ebikbwxiz',
#  'djjcwkw',
#  'cibueaejuno',
#  'yhqvwtq',
#  'fcfmaqwoe',
#  'bwdkadmppi',
#  'hnlfflfqvaktjsq',
#  'dlujyqwa',
#  'dwqqfdvo',
#  'jmqyvdkbdljnwx',
#  'ovvkfhfk',
#  'csfxzvtegefzb',
#  'jickbvevspeqz',
#  'ifnnsglagmub',
#  'mwbvxuplg',
#  'ozsvnsu',
#  'tytdwnpqvg',
#  'bnmixpjpuv',
#  'rhlpwnugd',
#  'cxwjnddwuuzuhn',
#  'wbwgqrkawjntwnh',
#  'loxvwtmase',
#  'mzpjgofwoofxi',
#  'vdggcqilsixyfds',
#  'gvocjao',
#  'zetrzxgbor',
#  'ovpnedl',
#  'uzeppqkkgmasb',
#  'vktlwrcadeesfbm',
#  'dyeqauzjusep',
#  'vumnhslacnpm',
#  'dpzfscnihyyhulg',
#  'nvzhrckgi',
#  'zkdewfgfxml',
#  'kmruzjvlnqvuj',
#  'gxkjlalgzrjytdy',
#  'cdfqazybthpiy',
#  'mpjqoskrykf',
#  'gbugxal',
#  'fnyncrvnzwvrhg',
#  'gmpajwytog',
#  'mrvuelmwfjndps',
#  'ccoqaswlvtqth',
#  'yyzhkhojkcw',
#  'ymzdmycogvdrmo',
#  'mlbnqaavqqdkon',
#  'uzjcdngamglaxi',
#  'hsecaotopu',
#  'bvgtjyszry',
#  'cvkebejbjqqxfi',
#  'ujlwrtrrzyiq',
#  'dytcxvoshlw',
#  'riqmvaapyrnrkb',
#  'pvlksgmhpfmx',
#  'dvmnomxua',
#  'oygwwmiyz',
#  'wdtbiyhgrnlqu',
#  'teyrpyv',
#  'yapyrfaiomflqik',
#  'ixubbfnpurs',
#  'avpiwlvzztbt',
#  'fejfjveehz',
#  'gaucngpuai',
#  'tgzaeuwmklm',
#  'uflxbkzssy',
#  'idyzqnofazqzuyv',
#  'yhclcacngio',
#  'mlpuiyuvmvykv',
#  'eziipajx',
#  'ljtmgqsgnhawh',
#  'sofdbkrcwfsmjc',
#  'bpqxcivtxyt',
#  'yvcnjcawszmsxa',
#  'ohiegqrpayrsiko',
#  'gutejygogqv',
#  'zwfazxgw',
#  'ndegnjai',
#  'moqnzsjqmbq',
#  'qmopdeb',
#  'druuslq',
#  'avbjfpnjjwxgec',
#  'mumzbuqlnbtmduv',
#  'lrceyusmvoz',
#  'elzjupwjwn',
#  'byxdblzj',
#  'apulaysongygq',
#  'krxbimuqggal',
#  'geexrskprxptc',
#  'tiorriapb',
#  'eyvwuxzjsckdrcc',
#  'fpwtkrxesziadx',
#  'oggziehjzwyobaw',
#  'hgyqprj',
#  'sshwvbpxckokjpu',
#  'amvakvelpsyxik',
#  'wgyvjfx',
#  'xurlctlkljzzg',
#  'zombnanbshliifg',
#  'zgpyhvnqp',
#  'mhxhfsyl',
#  'qkvuqmnhtprr',
#  'wwdvhlkl',
#  'xczekeyobmmtlu',
#  'rcjolwi',
#  'mjzqerglpvahr',
#  'mdhwikebg',
#  'fporlprryj',
#  'uvqyhtgnzttl',
#  'axyujdqt',
#  'mssshvxfwiv',
#  'ozmtqfjmimpry',
#  'wwsssbjajzgki',
#  'jacpmzjwnz',
#  'taiillw',
#  'sttbjbbvc',
#  'isvzroxkvqq',
#  'jtiopwxdxtfuuvw',
#  'pwwckyshoyl',
#  'yjzsaotizc',
#  'dfgmhtwkdmn',
#  'trgztqnx',
#  'awgjtjer',
#  'yqiorkiddw',
#  'vumjhpwyfcidf',
#  'ygwhxaudbhf',
#  'umnmqbuiabxyyg',
#  'tklfbytmaosly',
#  'pgrbizqxku',
#  'nqhnaddjmvzrxdo',
#  'zgsgkhrx',
#  'eimuvfovsaavwi',
#  'ddogfjubwfjjgw',
#  'fvtcuxx',
#  'vzmigerfc',
#  'djgcxhddxdyvrm',
#  'puvnvps',
#  'qwwoaxvpwo',
#  'uuvsqvmguewlc',
#  'hjcahlfvsr',
#  'cosfldvdzh',
#  'koswnntjommh',
#  'belmtqbrx',
#  'spthfqggwaiujjf',
#  'zuvskjmstywd',
#  'xrmdsgeuxbpa',
#  'fycekqrdcznmlkr',
#  'hcsslczqx',
#  'rtpcubhrzcvlxu',
#  'lzghcxy',
#  'dvnzbsrlixlfps',
#  'rdshtap',
#  'qhwxbglrtcfpxxy',
#  'zwxnoglmdtnza',
#  'efjfcfnsas',
#  'agitmjenoijmbg',
#  'bgywjzcwr',
#  'yjhropw',
#  'sgjzewzcgqbnm',
#  'rcygwej',
#  'wxjrpfcevpa',
#  'niaevukpsexoj',
#  'dcwictswxjj',
#  'ikvmfzgroo',
#  'tdidhesqvkncoom',
#  'nmarnlpanezveyp',
#  'rcvmqnjwyhjqz',
#  'easrcvwgvymu',
#  'exvouvflfsa',
#  'nauuhgh',
#  'txisfeymsbw',
#  'ekrykswgp',
#  'betnnha',
#  'adjzebfzkee',
#  'yyxwnvmexicr',
#  'ozsbukemclyjod',
#  'woebjmnhczu',
#  'grqspvaw',
#  'cgmacid',
#  'ipcqyqe',
#  'mkqfjrrz',
#  'tfbuwcwgb',
#  'dokuibgrdfzmc',
#  'fnzijre',
#  'umeohrtqpx',
#  'wzglatnail',
#  'obewyyxglfr',
#  'jtfqhpex',
#  'bjsebbayc',
#  'npritwrwhszrc',
#  'gcwnxhzcem',
#  'zxtmizboaruv',
#  'jtyfugxelgsa',
#  'hyafyhidqr',
#  'nljoqamdeosdq',
#  'vnxthawhwd',
#  'nstzssvnrsl',
#  'xzhlxnrtjr',
#  'obhgfwyaibkhi',
#  'xqhyndekcapko',
#  'khlskehyvq',
#  'ovighcuz',
#  'eoqpqsjnxml',
#  'xkwjivfr',
#  'rxylekloytc',
#  'nfyhnvonv',
#  'fxogsbl',
#  'cidyvbpisecnd',
#  'tffogjsyuctqdiy',
#  'nqssnhrf',
#  'nuicemzil',
#  'yyymfkz',
#  'jwbyxlzjveqjkcp',
#  'vamakwmckuad',
#  'xrilxazllbeyagn',
#  'hdmlmrfslg',
#  'xtxjgocc',
#  'szxaowtkcpkgw',
#  'sopnwjeutuh',
#  'qvqkkdcjfzuc',
#  'bkfvncejcfbzoxf',
#  'oevdeuvnp',
#  'sozrilnege',
#  'zpnzprd',
#  'ukvvpljopkk',
#  'ajigmanfnauycc',
#  'ywjmrgrkhmxdsat',
#  'fetvrvhkrht',
#  'bcqkxzsqnonymwj',
#  'gmcawytdzcmza',
#  'iclnmashd',
#  'rhsxfgmtc',
#  'wqgdacqzr',
#  'rutvhwg',
#  'ankkeqqsd',
#  'ilajierbtmyxja',
#  'ixwadutadl',
#  'iueeqhspihulf',
#  'fjfroojohktkv',
#  'urdsmzl',
#  'rxdvdcwn',
#  'mfnvugto',
#  'meapvdtyhnew',
#  'kxmlihswifr',
#  'rauvqmeh',
#  'dgsocelxbsubhth',
#  'rbvtxszbvkj',
#  'vpjrmnjofkpidev',
#  'emhcbbwzh',
#  'zisjakpvbothem',
#  'viygeoyhvtubwim',
#  'xemvjkiy',
#  'dbltpmxgnle',
#  'idhqodafjdmj',
#  'nqecydmqxygyx',
#  'utrbsftt',
#  'fqpicmvazthdh',
#  'epxgwxhzaogm',
#  'tqydqncnaiora',
#  'xuusftpnc',
#  'wehrbtppb',
#  'jlwzdkbxbina',
#  'yhnewxrmrpghfju',
#  'phrcptzcfnbw',
#  'ovgxjxadrubnj',
#  'fkkmrduf',
#  'amrewbltdcjc',
#  'mpxqjqvfakyf',
#  'orqnjnwuumazidn',
#  'vpogvjodca',
#  'ccfajjguc',
#  'ejbklojjcgqt',
#  'uiulalwig',
#  'achsmaue',
#  'jwhqamtetkwomfk',
#  'lastleynfy',
#  'gfdougolny',
#  'vicfbhjtju',
#  'skwtetcgapbsoi',
#  'tzgfchvnbruwged',
#  'vhanuzrwaffpd',
#  'vccngwrir',
#  'zbfoktzxz',
#  'gsduqbsaskfyedt',
#  'yphxrctq',
#  'fwwdxjkckvsg',
#  'auiklucawslj',
#  'txgigjr',
#  'zwjebwbkgzufz',
#  'vxvwzmcsjyfqhn',
#  'wtyiskwtsw',
#  'sctqreozrnyvvy',
#  'irulzxcd',
#  'giymfbrgfmtrmnd',
#  'zrkwbszimpc',
#  'cdrbowvj',
#  'eaguemzqjc',
#  'efjxaioxqdo',
#  'ydrvtujj',
#  'psmqdstutkqw',
#  'geqhnsmbstecags',
#  'nwxsxtfdxvs',
#  'lhpzjqqhw',
#  'ermixfpvcyyor',
#  'dgayecxevnszqrj',
#  'hzqoyxnemhy',
#  'enzodjkhqsm',
#  'fawydrjnza',
#  'pnqbyrzzzrzk',
#  'iwnpxxzycwxkty',
#  'oareusktjb',
#  'aejuybvgjzob',
#  'gmpfjkueubcol',
#  'qhhofxhj',
#  'rgkjkylauynvuql',
#  'uxvanzsaxdxpx',
#  'qbezhzrb',
#  'jnyrylzbcw',
#  'mketleugcsmrjlc',
#  'hiwveexyrllqpc',
#  'hzkcmbrwknabq',
#  'ffohebzkdzex',
#  'wjjkhtvrnci',
#  'bvytjtpy',
#  'uypfcpnj',
#  'dzrcyfzdzmp',
#  'zysiwealzlgyrd',
#  'oyfzcwxg',
#  'ltgkksai',
#  'ecjvbpctase',
#  'komgyurewre',
#  'oknvejyrysybg',
#  'cngamgmk',
#  'uxzwjkpv',
#  'jevrcozsdfk',
#  'axyuflvylcwb',
#  'jvdhkgflwgdwhoq',
#  'pjzzbzaxdbjku',
#  'iifeojfnipm',
#  'mqgvytujrqxms',
#  'wjrknfwswivoil',
#  'qhdwzosalgzwhi',
#  'tttylabjx',
#  'saypyhsgcj',
#  'jtnnhueakoqe',
#  'pghjfjcqzljozk',
#  'svwgqmlk',
#  'txselrp',
#  'vkpswlnom',
#  'ycalydnkgnmgi',
#  'jtzpcqa',
#  'smsndvpz',
#  'dvmxfdmsbelism',
#  'bdegguvqmtoqml',
#  'vksztnb',
#  'hmhstxnylklln',
#  'qsltmnn',
#  'vblsbxaxnhj',
#  'zbqpamysbgahjbf',
#  'ylfxdxb',
#  'yjmehhuynfj',
#  'dpcjvpy',
#  'wmwlcnyrvvksj',
#  'dhtcoat',
#  'xnpkhqap',
#  'yjnxcjdcbdg',
#  'jyywrjbzvny',
#  'jfhsfwvanb',
#  'gvoeujxj',
#  'qlgqohovesfehjx',
#  'bgiflggk',
#  'irvvixrlsxz',
#  'upnypkxzghefakr',
#  'fqqopkjywxcyyq',
#  'rqfszcgxrccd',
#  'oulowokltpx',
#  'fhpesmzyxayru',
#  'dyaudgp',
#  'sgzwcyg',
#  'figvjkrt',
#  'tytpzkykl',
#  'upfbgxmzysnpbb',
#  'wsqwdhmjl',
#  'epfyexwxjef',
#  'qebnojggkeb',
#  'skvvktwbaqeudt',
#  'kolplzcitx',
#  'edtisacde',
#  'vakufdf',
#  'gotzmqker',
#  'exbzossneacgtb',
#  'nslmoxzt',
#  'rkpfedvuk',
#  'qmapdpiksfaiqws',
#  'awhpgjeilgeqtzp',
#  'aqfuarluilhhalu',
#  'jpludqkogzkuxe',
#  'pcsrjmthqqcburr',
#  'geouhhl',
#  'tzpymcrnlkh',
#  'rmuglfbsxehdy',
#  'pcettyvy',
#  'fbumzqilf',
#  'qacfvxmdoeaift',
#  'yxzhozhknsy',
#  'hbuvregrrbhmcys',
#  'dwsvupafylr',
#  'nthprad',
#  'ozkeaksknmsa',
#  'fdtdyfkdjvdejy',
#  'evomutzkn',
#  'jjqvdry',
#  'hinswllxnucgp',
#  'gfmoaazendvc',
#  'ikkwfrqscfqp',
#  'gzccoivcnkp',
#  'ipxpbdyvlzdjrb',
#  'psxrfrqtcen',
#  'mcytzdrkqj',
#  'ladkluyqzg',
#  'rnyibbwipx',
#  'wlzhutjjsc',
#  'ntzwhlsljvqq',
#  'yfnmbeqmjdgsmj',
#  'icyhbytapygd',
#  'pltdnultf',
#  'hfmesdgisece',
#  'szxpgkazkfs',
#  'cavqoymorusuco',
#  'livlmbbddpxz',
#  'kdrdgzhwlp',
#  'tfmhzitkct',
#  'yfbjiiteaxcaee',
#  'ftjybxh',
#  'hlnzapzcbdvm',
#  'srbbpvyehw',
#  'lmfdokvt',
#  'cgfsybzdcdf',
#  'rzntiew',
#  'vqpfvykozi',
#  'ggrapvbtjxiy',
#  'xsyuzdxw',
#  'vvxrrowttbrzevz',
#  'tlfcrazal',
#  'xqophew',
#  'kfyaqwshuna',
#  'ewihmvftobn',
#  'ovdfuirdz',
#  'gpdmdvpipho',
#  'mgqpdnbcdg',
#  'baxesmdjg',
#  'bbcfcqgxzeytlp',
#  'gazkqazzwscvxm',
#  'cfpiufvdsmkcm',
#  'nlekagfezd',
#  'ieshpppio',
#  'hyoimwiwqw',
#  'cjtdyfzyvdlwra',
#  'wnhmrwezcgbnjdb',
#  'egmzsnpta',
#  'tisdimqapwsbjj',
#  'rxuyolucemxhnn',
#  'pvnoqgmbthp',
#  'iysacahlbjp',
#  'nllmatydstv',
#  'jvrsqkvdrlyyqs',
#  'lqzsuvbryy',
#  'hoetjlfsarp',
#  'swfcfowb',
#  'rhbqxnkeg',
#  'pbsquekqmxteq',
#  'ukgnbfx',
#  'jirdgfuquxtx',
#  'lisnmkmqbwddws',
#  'cceagpbjjzd',
#  'gjfdajcmf',
#  'tlvevhnaja',
#  'qnimvzqpm',
#  'cgsdtnpkxlvzld',
#  'oqipybwvm',
#  'etzuxhj',
#  'jcvdsgz',
#  'rwmwhvxlanuyu',
#  'deeupncpbxupd',
#  'dgoblhfhwgtspx',
#  'qicbkevx',
#  'qrxmghlgzv',
#  'tgrvrlrvszfu',
#  'vrdjpdsybothmp',
#  'ncrxporwdgfa',
#  'hablnzanrkxbdrs',
#  'fibjnytb',
#  'wwevggktylzica',
#  'rdtoognra',
#  'jxbthbbor',
#  'cbzokdhodhjc',
#  'ylbwnbzv',
#  'cijyzdtpab',
#  'mugwxjmzcizv',
#  'vnjawlu',
#  'olohqwxa',
#  'fvtcugmdhozw',
#  'zvxnfvdtewyvcz',
#  'qumfddlpsdhltgh',
#  'jolmuzbnvbul',
#  'iwufweyu',
#  'jghuvpzmrurdlw',
#  'rjvajdjuti',
#  'aadtjmhkeb',
#  'letnnqofgcc',
#  'ejkcllljyqtc',
#  'gjezeybcqveuz',
#  'dphspqtnu',
#  'nmofywyhzc',
#  'nahgdhjcqi',
#  'shrwyvybbkfqod',
#  'koiddypdrszg',
#  'kjhvgrvmhdmihji',
#  'tytrwoqspqkito',
#  'ekhkakn',
#  'xhkrvjx',
#  'ihzcmdoxvtojrzg',
#  'fgaryojwpv',
#  'gowmxeikugilpvg',
#  'wamllwahwacn',
#  'zudfychdhw',
#  'oggaosqsvy',
#  'fyluaeqqfp',
#  'nbngkzfiudkh',
#  'hxtigyhmrmhg',
#  'rysybkugyfc',
#  'pwjyzgmdzj',
#  'slltxdfn',
#  'wfiigqszczdbv',
#  'aqcasvcpb',
#  'minpzbroo',
#  'mcmmjvpfzua',
#  'nnhmclxp',
#  'dvpthxvcyq',
#  'zsafclugqqqdxhv',
#  'fomtmgzkmnqgb',
#  'rkupbslcdolma',
#  'ekltaeeiiebyyzg',
#  'gpnpncxoz',
#  'fcpscdhqhtwqdi',
#  'rvbmqtm',
#  'ednsmqajzxxitso',
#  'brucrjo',
#  'tobquqjhev',
#  'twuafelgihjcumb',
#  'nmvyyjmybkqes',
#  'tehulgf',
#  'bnrtwkbwtg',
#  'azzjnxfvhfcaby',
#  'btaeestotvd',
#  'wcrolmrdyztd',
#  'keoioisqlk',
#  'xwxryawgmjy',
#  'hexipudkym',
#  'aggzjupplgai',
#  'zvdmubherzrff',
#  'fpwstuoyzdmpsxw',
#  'hlwvweydwbronef',
#  'zqtfyhj',
#  'ipkaxkoq',
#  'gaunpxfceawwhnu',
#  'qcqryflktfjy',
#  'truycchjabih',
#  'ptqgrfskkz',
#  'yviqhppp',
#  'kllsjiwtmdmw',
#  'fhffylgwvszt',
#  'mudbnlrogmh',
#  'xmitqrwftledan',
#  'ljqnvmjknrsga',
#  'mnvcnyyiddnnvr',
#  'mkzqffwihubr',
#  'orkbqfaksv',
#  'iahtmzypcebryy',
#  'fcqsitejtdjksdr',
#  'pqhwpfcheujqox',
#  'owvbijtprbuoi',
#  'rfvzsvljhaq',
#  'scjyqeyfyweuwx',
#  'royhwzi',
#  'fejazeib',
#  'zeqquxdqlbgctqr',
#  'wcpmzzbaqcu',
#  'fchixvgovaedzzg',
#  'jkfcxmb',
#  'sbrneqkoit',
#  'mgcvfkg',
#  'qtxwmhwaj',
#  'lqpymbppvtk',
#  'wjosbjstpdotd',
#  'cbmdepzupjqls',
#  'ftnoymgh',
#  'mizcgrc',
#  'hihsitboovzawa',
#  'verjuir',
#  'ttxtpsjigdort',
#  'nctpkxhoo',
#  'tcbdmiw',
#  'onpftdcrmh',
#  'svizkcg',
#  'nxuwwsq',
#  'hcghsadvcsux',
#  'rcpvvdefhspyrki',
#  'opdqequqvagbk',
#  'vxfypcy',
#  'ueqmyue',
#  'vlmkvdvys',
#  'qjdqdws',
#  'kbgjmcn',
#  'bhmzrwgddlsvxch',
#  'szyoyomub',
#  'xqaxxoxfaj',
#  'nwmktjfamgkt',
#  'khwsrihgd',
#  'ffsmezqsou',
#  'avdggzmfqlqu',
#  'fxfgfxwcczzn',
#  'tclwxkieach',
#  'shwxrwwave',
#  'bdzsonrloc',
#  'jtbvmducmmj',
#  'sjdvgsqn',
#  'goeqkqojzlz',
#  'fruqxlr',
#  'cpvlrkkzg',
#  'ghsfrxlxyftatqg',
#  'tlznutwpi',
#  'ecyxzsnaglp',
#  'pksqsgjd',
#  'rbimbndxnvg',
#  'hyycquurzx',
#  'bmikjknalzjrnku',
#  'otcvhfiv',
#  'dogcpbwizmbmjw',
#  'ilnuyupygvkq',
#  'nxgvgrxikbf',
#  'sdmltbgxedv',
#  'jdbviyakfl',
#  'vdcynrmkjw',
#  'qcmzmlvmusmqzwq',
#  'fexyzqmahtqva',
#  'cghuwmcxin',
#  'kjihtmfohwb',
#  'rjlvbiln',
#  'awupvvchgulngj',
#  'xwasxzgiqkct',
#  'yphhgqdykb',
#  'wmcvkppmikri',
#  'pvpmfcyb',
#  'lwevfatemxnscr',
#  'koofdzrj',
#  'gerghzwcwsrshtf',
#  'mtxlpep',
#  'vvfhhssw',
#  'qirtlzrdvy',
#  'ocbqqsmyvorpqis',
#  'vhjxqehttwibbt',
#  'jafymhsyqqga',
#  'jktogzkbz',
#  'phqpvkqstwc',
#  'dpoqbkpeotppeb',
#  'gvyzqfskadb',
#  'ckbvtsm',
#  'tjzgpybatcgrta',
#  'tbflbhr',
#  'ztzavihrzx',
#  'jprtdidpxm',
#  'egxafywb',
#  'glzzvhojz',
#  'wnjnuqvmvxxvmk',
#  'kpjpfxnklyeson',
#  'dxidtaip',
#  'egueepzi',
#  'lamprtrnlaat',
#  'rwxjwxrobyb',
#  'egrujjzvbrb',
#  'iqfxodchpy',
#  'apznudnhzj',
#  'fbeuwomtn',
#  'nxnhsazveosuz',
#  'rkliepntgdt',
#  'fyqsmdjtytt',
#  'kerfrcks',
#  'naaapdj',
#  'jfcdzxfmfopi',
#  'pwzajwradkpb',
#  'bhmstunsroznks',
#  'vhrewtxd',
#  'zggzofrqqmaoa',
#  'fbdhnlcmkgjkwl',
#  'wandfboccu',
#  'tgwlrlviozygytq',
#  'owuwhoullsgb',
#  'etfwtmy',
#  'pendunfkcip',
#  'reprehrok',
#  'dcxyzlobzfhyg',
#  'sdljnyutjonbbuu',
#  'qtdyknf',
#  'feazytztkbzuowj',
#  'zbpkrnopzpnmcv',
#  'mhxeneb',
#  'oclzwwobcsrqxg',
#  'bnnxyxmvui',
#  'rxmbwvt',
#  'ozadlakorqoe',
#  'dsoptflijbwb',
#  'esqgvbofzmw',
#  'czzapleyqcq',
#  'ptnkyfw',
#  'uymsiby',
#  'gtuuojf',
#  'jtaxqjlpsiudypz',
#  'gkmgfmtpe',
#  'knixsbkwyyhugk',
#  'bxmbkttkpmzxob',
#  'nfbnjuwd',
#  'ghrlnhbjxnork',
#  'cpadczipohawafo',
#  'edbasvfe',
#  'wwygnkt',
#  'iicwhvghhk',
#  'jtmuuokfmjmtz',
#  'smahqdotvdfxz',
#  'lprxwyj',
#  'somgzfhwmsv',
#  'djbmjdzjn',
#  'fuzzicnfwokzzl',
#  'tzglhmb',
#  'oqnfrygzxzwo',
#  'eoeqzgg',
#  'cbgawuvelakubtf',
#  'fjqkzuk',
#  'zxilaamaoujnpr',
#  'wxcmhyrsaitafhp',
#  'oocvnkaxcblehjr',
#  'utsaqqes',
#  'kivhfzqaxe',
#  'lkravpygoqxt',
#  'cdjfdnmjszzv',
#  'cshopnooutd',
#  'xaoylaljsiqalf',
#  'pixlehebd',
#  'gvjhzdwbbnw',
#  'kvjmxntddeuc',
#  'hxjxodfzvxbwtf',
#  'toorkzzo',
#  'jvsgjpkiohpcrk',
#  'gyibenncpl',
#  'cxkugma',
#  'guzgyddsj',
#  'ycmbtqiowir',
#  'rhuqpapn',
#  'plbvproius',
#  'mmbuyidyfxyyns',
#  'vpkfvzoraqoyb',
#  'ofpliowtw',
#  'vlqydgpfl',
#  'fqboqucocaruwi',
#  'tbjaoofxzcflh',
#  'yejgkrilvoo',
#  'fnxldsxfupfs',
#  'xoeebhdsidxh',
#  'lflkyegztiu',
#  'dhvnwqsj',
#  'ipfiwtoerfqq',
#  'jucdoeshigrnjh',
#  'noxdttflb',
#  'dleghmiyewt',
#  'dzofjxgwvfbhuct',
#  'kbnumydg',
#  'ugccvtphilkgmfg',
#  'oxbmrimktecs',
#  'gqwprvuuwdtj',
#  'nwhslhhkofznw',
#  'ybzbhqgwg',
#  'yekhuch',
#  'mndypadnz',
#  'bxjwvvyuhage',
#  'vyrboje',
#  'zmraqxsonxun',
#  'wwnqrqt',
#  'xshlkyp',
#  'tvjxztjofg',
#  'iucxrhejb',
#  'cnivwiqchdxewo',
#  'yuhoylgd',
#  'hgqednbce',
#  'vzymygkekdyha',
#  'yphdxhsmyoxaqmx',
#  'itvmdegtfpiudd',
#  'vvtnzzx',
#  'irddwxq',
#  'vxhfuirt',
#  'rrxfrizgrwvn',
#  'lajjucgmcs',
#  'jkszqfunyb',
#  'elwgmpntj',
#  'cfmlqswfch',
#  'xbtoxldvlr',
#  'mqwtmrombghguxa',
#  'mqykvsm',
#  'lyrhiwqsswy',
#  'octflxiydf',
#  'xnoydjek',
#  'sxkxaqorhuqohc',
#  'zmgzqia',
#  'xfbxvxvyri',
#  'dakvjbdbjhgemv',
#  'hxcqkrgcf',
#  'hcghokjmx',
#  'tudfrzhnqa',
#  'rnewgrvjngv',
#  'ewinedxqflg',
#  'lykocxqdybj',
#  'bdptibhzowkbpbn',
#  'hfmmtjygxhdnlg',
#  'sjjeruuubft',
#  'xxvybxszpv',
#  'wmlegedfixlm',
#  'kioaavzsi',
#  'jfbqost',
#  'syzkcnnunkjzs',
#  'wliouldxhyl',
#  'xnosmvmtrfxglb',
#  'qgrklidxctucz',
#  'vzlcpnxbm',
#  'oiivxhf',
#  'xbpnucutkjhir',
#  'bxjfmeif',
#  'dwsxiwuszg',
#  'jbcprfxeob',
#  'kfyyuwyt',
#  'dgjwrjhcjooh',
#  'hndzvrlcgzvoxhj',
#  'izyhkzghrsaxmq',
#  'gjcgahgdlbutlin',
#  'oxecdftni',
#  'ovldjhp',
#  'bvsatfanyq',
#  'reddumrekuexijh',
#  'ohgjriryhlx',
#  'vafisnndj',
#  'kqrbssegvvs',
#  'hmlsfcfpmt',
#  'fkafuicohsnec',
#  'iyqcqiiylenwcj',
#  'rmxnpestzpzawn',
#  'lffxrpgv',
#  'niaudyonnbndfbn',
#  'phajnoxadpjza',
#  'joeekvwk',
#  'elhvymp',
#  'uwgejnqvyfx',
#  'mtmfxohxkucsmg',
#  'jadmnebywdas',
#  'bqeqfukaihx',
#  'kuulzomixi',
#  'qawemijhyf',
#  'njruwmcmwq',
#  'eqwckimiqo',
#  'jrzybdews',
#  'dxxccsxfqrfie',
#  'yfijojtdpwq',
#  'jgtdrljxcvw',
#  'xjulcej',
#  'sdobatrxade',
#  'zlmbptucw',
#  'bpbcuxlpgxjihxu',
#  'dahtcizlgljwmo',
#  'psenlvdm',
#  'hvqqxlzywvcxp',
#  'howfmwkmcxkuzfh',
#  'ixdsxznsk',
#  ...}

# %% [markdown]
# # Data To Chunks

# %%
users_queries = []
for user in users_data:
    users_queries.append(list(user.loc[user['dns.flags.response'] == 0]['dns.qry.name']))

users_queries_split_by_chunks = []
for user_queries in users_queries:
    number_of_chunks = len(user_queries)
    user_queries_split_by_chunks = []
    for i in range(int(number_of_chunks / NUMBER_OF_QUERIES_EACH_CHUNK) + 1):
        user_queries_split_by_chunks.append(
            user_queries[i * NUMBER_OF_QUERIES_EACH_CHUNK:(1 + i) * NUMBER_OF_QUERIES_EACH_CHUNK])
    users_queries_split_by_chunks.append(user_queries_split_by_chunks)

# %% [markdown]
# # Build Main dataframe

# %%
"""
***only queries

df:
user-id chunk-number


"""
df = pd.DataFrame(columns=['User', 'Chunk']).set_index(['User', 'Chunk'])

# common domains - number of apperance of most 50 domains(which not everyone use)
top_100_common_domains = list(domains_usage_count_df.iloc[:COMMON_DOMAIN_COUNT]['domains'])
top_100_common_domains = set(top_100_common_domains)
for user_id in range(len(users_queries_split_by_chunks)):
    for chunk_id in range(len(users_queries_split_by_chunks[user_id])):
        for domain in top_100_common_domains:
            df.loc[(user_id, chunk_id), domain] = users_queries_split_by_chunks[user_id][chunk_id].count(domain)

# remove data not needed:
df = df.reset_index()
df = df.loc[df['Chunk'] < USEABLE_CHUNKS]
df = df.set_index(['User', 'Chunk'])

# %% [markdown]
# # Create Classifiers

# %%
### Add labels ###:
for user_id in range(NUMBER_OF_USERS):
    df['label{}'.format(user_id)] = pd.Series([0] * USEABLE_CHUNKS * user_id + [1] * USEABLE_CHUNKS + [0] * USEABLE_CHUNKS * (NUMBER_OF_USERS - 1 - user_id), index=df.index)

# %%
### create train_x train_y
features = df.reset_index()

train_x = features.loc[features['Chunk'] < LEARNING_CHUNKS].set_index(['User', 'Chunk'])  # features without labels (first 50)
train_x = shuffle(train_x)
train_y = pd.DataFrame({"label{}".format(i): list(train_x.pop("label{}".format(i))) for i in range(NUMBER_OF_USERS) }) # only labels (first 50)
train_x = train_x.reset_index()
train_x.pop('User')
train_x.pop('Chunk')
# Out:
# 0      48
# 1      24
# 2       2
# 3       0
# 4      24
# 5      38
# 6      16
# 7       5
# 8      43
# 9       7
# 10     17
# 11      9
# 12     33
# 13     31
# 14     44
# 15     39
# 16      5
# 17     32
# 18     45
# 19     20
# 20      9
# 21      1
# 22     44
# 23     46
# 24     30
# 25     22
# 26     20
# 27     10
# 28     17
# 29      7
#        ..
# 720    40
# 721    18
# 722    28
# 723    47
# 724     3
# 725    41
# 726    21
# 727    19
# 728    32
# 729     4
# 730    34
# 731    17
# 732    14
# 733    49
# 734    47
# 735    46
# 736    15
# 737    36
# 738    22
# 739    29
# 740    43
# 741    38
# 742    22
# 743    12
# 744    47
# 745    12
# 746     3
# 747    11
# 748    23
# 749    11
# Name: Chunk, Length: 750, dtype: int64

# %%
# Create test_x, test_y
test_x = features.loc[features['Chunk'] >= LEARNING_CHUNKS].set_index(['User', 'Chunk'])  # features with label (last 40)
test_y = pd.DataFrame({"label{}".format(i): list(test_x.pop("label{}".format(i))) for i in
                        range(NUMBER_OF_USERS)})  # only labels (last 40)
test_y2 = pd.DataFrame(columns=['User', 'Chunk']).set_index(['User', 'Chunk']) # only labels (last 40)
for user_id in range(NUMBER_OF_USERS):
    for chunk_id in range(LEARNING_CHUNKS, TESTING_CHUNKS + LEARNING_CHUNKS):
        test_y2.loc[(user_id, chunk_id), 'label'] = user_id
test_x = test_x.reset_index()
test_x.pop('User')
test_x.pop('Chunk')
# Out:
# 0      50
# 1      51
# 2      52
# 3      53
# 4      54
# 5      55
# 6      56
# 7      57
# 8      58
# 9      59
# 10     60
# 11     61
# 12     62
# 13     63
# 14     64
# 15     65
# 16     66
# 17     67
# 18     68
# 19     69
# 20     70
# 21     71
# 22     72
# 23     73
# 24     74
# 25     75
# 26     76
# 27     77
# 28     78
# 29     79
#        ..
# 570    60
# 571    61
# 572    62
# 573    63
# 574    64
# 575    65
# 576    66
# 577    67
# 578    68
# 579    69
# 580    70
# 581    71
# 582    72
# 583    73
# 584    74
# 585    75
# 586    76
# 587    77
# 588    78
# 589    79
# 590    80
# 591    81
# 592    82
# 593    83
# 594    84
# 595    85
# 596    86
# 597    87
# 598    88
# 599    89
# Name: Chunk, Length: 600, dtype: int64

# %%
### train ###
models = []
t1 = time()
print("Started XGBClassifier in", t1)
for i in range(NUMBER_OF_USERS):
    model = XGBClassifier()
    model.fit(train_x, train_y['label{}'.format(i)])
    models.append(model)
t2 = time()
print('Finished XGBClassifier in ', t2, ' Total time ', t2 - t1, ' sec.')
# Out:
# Started XGBClassifier in 1560259744.989995
# Finished XGBClassifier in  1560259749.174502  Total time  4.184506893157959  sec.

# %% [markdown]
# # Test Results

# %%
# check predictions:
preds = []
for i in range(NUMBER_OF_USERS):
    preds.append(models[i].predict_proba(test_x))

# %%
# check accuracy 1:
predictions = pd.DataFrame(columns=["label{}".format(x) for x in range(NUMBER_OF_USERS)])
for chunk_number in range(TESTING_CHUNKS * NUMBER_OF_USERS):
    predicted_user_id = np.argmax([preds[user_id][:,1][chunk_number] for user_id in range(NUMBER_OF_USERS)])
    new_col = {"label{}".format(x):0 for x in range(NUMBER_OF_USERS)}
    new_col["label{}".format(predicted_user_id)] = 1
    predictions = predictions.append(new_col, ignore_index=True)

predictions.eq(test_y.values).mean() # calculate accuracy for each user separately
# Out:
# label0     1.000000
# label1     0.998333
# label2     1.000000
# label3     1.000000
# label4     0.998333
# label5     0.973333
# label6     1.000000
# label7     0.998333
# label8     0.998333
# label9     0.998333
# label10    1.000000
# label11    0.996667
# label12    1.000000
# label13    0.975000
# label14    1.000000
# dtype: float64

# %%
# check accuracy 2:
predictions2 = pd.DataFrame(columns=['User', 'Chunk']).set_index(['User', 'Chunk'])
for user_id in range(NUMBER_OF_USERS):
    for chunk_id in range(LEARNING_CHUNKS, TESTING_CHUNKS + LEARNING_CHUNKS):
        real_chunk_id = chunk_id-LEARNING_CHUNKS + user_id * TESTING_CHUNKS
        predicted_user_id = \
            np.argmax([preds[i][:,1][real_chunk_id] for i in range(NUMBER_OF_USERS)])
        predictions2.loc[(user_id, chunk_id), 'label'] = predicted_user_id

accuracy = accuracy_score(predictions2, test_y2)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 96.83%
